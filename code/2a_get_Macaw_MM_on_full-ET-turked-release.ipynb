# %% [markdown]
# This notebook illustrates how we:
#
# - Query Macaw on everyday things
# - Perform constraint reasoning on top of Macaw's outputs based on device + parts list

# %% [markdown]
# #  Part1: Prompt the model to get its MM of a device

# %%
from utils import *

# %%
make_sure_dir_exists("saved_logs")
make_sure_dir_exists("macaw_query_beaker_input")

# %%
import csv
import json
import ast
from csp import *

# %% [markdown]
# Set up beaker. Let's use beaker-py to run experiments on beaker -- no more yaml scripts! :)
#
# To learn more about beaker: https://beaker-docs.apps.allenai.org/
#
# NOTE: Before you run the following cells, change to the appropriate workspace_name of yours.

# %%
#!pip install --upgrade beaker-py

# %%
#!pip install beaker-py
from beaker import *

workspace_name = "<your_workspace>"
beaker = Beaker.from_env(default_workspace=workspace_name)
# check who you are logged in as 
print(beaker.account.whoami().name)
# Out:
# yulingg

# %% [markdown]
# Load annotated data

# %%
et2triplets_ann = {}
with open("enriched_mms/full-ET-dataset.tsv", "r") as dataset:
    lines = csv.reader(dataset, delimiter = "\t")
    for line_idx, line in enumerate(lines):
        # skip header
        if line_idx == 0:
            continue
            
        # per MM as in an everyday thing sketched by a turker
        et_turker = (line[0].replace("-", " "), line[1])
        if et_turker not in et2triplets_ann:
            et2triplets_ann[et_turker] = {"triplets": [], "parts-list": []}
           
        # collect list of (triplet_tuple, True_False_label)
        triplet = ast.literal_eval(line[2])
        annotated_relation = (triplet, line[3])
        assert annotated_relation not in et2triplets_ann[et_turker]["triplets"]
        et2triplets_ann[et_turker]["triplets"].append(annotated_relation)
        
        # also collect a list of unique parts
        for part in (triplet[0], triplet[2]):
            if part not in et2triplets_ann[et_turker]["parts-list"]:
                et2triplets_ann[et_turker]["parts-list"].append(part)

# %% [markdown]
# # Batch mode
# ## Generate queries to batch query macaw
# Macaw's MM is only dependent on the everyday thing and the parts. Each query depends on the everyday thing, and triplet. We query Macaw for unique queries only (i.e. do not repeat the same question twice).

# %% [markdown]
# ### Note: creating this file takes a few minutes. You may comment out this section of the code after running it just once!

# %%
with open("macaw_query_beaker_input/macaw_query_full-ET-dataset.json", "w") as query_outfile:
    seen = {}
    for et_turker in tqdm(et2triplets_ann):
        et, turker = et_turker
        parts_list = et2triplets_ann[et_turker]["parts-list"]


        # permutation of list of parts
        perm = get_parts_perm(et, parts_list)

        # for all permutations
        for entry in perm:
            for rln in all_relations_lst:

                # form statement
                triplet = (entry[0], rln, entry[1])
                statement = triplet2statement(triplet)

                # form questions
                mc_list = ("True", "False")
                mcoptions = " ".join(["(" + chr(i+65) + ") " + word for i, word in enumerate(mc_list)])

                et = et.replace("-", " ")
                et_triplet = (et, triplet)
                if et_triplet not in seen:
                    
                    compiled_qns = "Judge whether this statement is true or false: In {determiner} {device}, {statement}.".format( \
                            determiner = get_determiner(et), device = et, statement=statement)
                    query_outfile.write(json.dumps({"id": str(et_triplet) + "-originalTF", "question" : compiled_qns, "mcoptions": mcoptions,
                        "angle":[["question","mcoptions"],["answer"]], "explicit_outputs": mc_list}))
                    query_outfile.write("\n")
                    
#                     # Ignore ngegated statements for now (Macaw may not handle negation well)
#                     neg_compiled_qns = "Judge whether this statement is true or false: In a/an {device}, it is not the case that {statement}.".format( \
#                             device = et, statement=statement)
#                     query_outfile.write(json.dumps({"id": str(et_triplet) + "-negatedTF", "question" : neg_compiled_qns, "mcoptions": mcoptions,
#                         "angle":[["question","mcoptions"],["answer"]], "explicit_outputs": mc_list}))
#                     query_outfile.write("\n")

                    seen[et_triplet] = 1
                else:
                    seen[et_triplet] += 1
# Out:
# 100%|████████████████████████████████████████████████| 300/300 [09:18<00:00,  1.86s/it]

# %%
print(len(seen), "unique queries")
# Out:
# 108528 unique queries

# %% [markdown]
# 108528 unique queries

# %% [markdown]
# ## Upload dataset
#
# (only need to be done once)

# %%
#Store as <dataset-name> using data from <local-source>
dataset = beaker.dataset.create("full-ET-dataset-2022Dec16", "macaw_query_beaker_input/", quiet=True, strip_paths=True)

# %% [markdown]
# ## Run experiment

# %%
myimage = beaker.image.get("oyvindt/MultiAngleV50")
model_used = "oyvindt/maqaw_11B_v1"
#model_used = "oyvindt/maqaw_large_v1" 
#model_used = "oyvindt/maqaw_3B_v1" 
#model_used = "oyvindt/multi-angle-union2-ang1-large-hf" ##HERE - model type 

qns_type = "full-ET-dataset"
experiment_name = "Macaw-11B_zero-shot_Decision_on_" + qns_type + "_2022Dec16"##HERE - model type

input_dataset_name = "yulingg/full-ET-dataset-2022Dec16"
input_jsonl_file_name = "macaw_query_full-ET-dataset.json"

beaker_cluster_name = "ai2/general-cirrascale"
#beaker_cluster_name = "ai2/aristo-cirrascale"
#beaker_cluster_name = "ai2/mosaic-cirrascale"
#beaker_cluster_name = "ai2/allennlp-elanding-rtx8000"

# %%
spec = ExperimentSpec(
    tasks=[
        TaskSpec(
            name="predict",
            image=ImageSource(beaker=myimage.id),
            command=["python", "multi_angle/run_maqaw.py", "--model_name_or_path", \
                        "/inputs/model", "--input_files", "/inputs/data/" + input_jsonl_file_name, \
                       "--output_dir", "/output", "--n_gpu", "2", "--add_metrics", \
                       "--eval_batch_size", "4", "--num_beams", "1"], # gpu
            datasets=[DataMount(mount_path="/inputs/model", source=DataSource(beaker=model_used)),\
                     DataMount(mount_path="/inputs/data", source=DataSource(beaker=input_dataset_name))],
            resources=TaskResources(gpu_count=2, memory ="100GiB"), # gpu
            context=TaskContext(cluster=beaker_cluster_name),
            result=ResultSpec(
                path='/output'  # required even if the task produces no output.
            ),
        ),
    ],
)

# %%
experiment = beaker.experiment.create(
    experiment_name,
    spec,
    workspace=workspace_name,
)

# %% [markdown]
# ## Process predictions from macaw

# %% [markdown]
# The following assumes you are storing the predictions as Macaw-11B_zero-shot_Decision_on_full-ET-dataset.jsonl inside macaw_query_beaker_output/, placed in the same directory as this notebook.

# %%
model_name = "Macaw-11B"
# model_name = "Macaw-3B"
# model_name = "Macaw-large"
# model_name = "UnifiedQA"
# model_name = "gpt3-text-davinci-003"

# %%
# !mkdir macaw_query_beaker_output

# %%
et_triplet_2_probTF = {}
with open("macaw_query_beaker_output/" + model_name + "_zero-shot_Decision_on_full-ET-dataset.jsonl", "r") as predfile:
    prediction_data = predfile.readlines()
    for prediction in prediction_data:
        json_pred = json.loads(prediction)
        #print(json_pred)
        
        et_triplet_str, original_negated_label = json_pred['id'].rsplit("-",1)
        #print(et_triplet, original_negated_label)
#         et = et_triplet_str.split(",", 1)[0]
#         et = et.replace("-", " ")
#         et_triplet_str = et + "," + et_triplet_str.split(",", 1)[1]
        
#         # Ignore ngegated statements for now (Macaw may not handle negation well)
#         if "negated" in original_negated_label:
#             continue
        
#         if et_triplet_str in et_triplet_2_probTF:
#             continue
            
        assert et_triplet_str not in et_triplet_2_probTF
        et_triplet_2_probTF[et_triplet_str] = {"answer": None, "prob_True": 0, "prob_False": 0}
        
        # Get answer label
        et_triplet_2_probTF[et_triplet_str]["answer"] = json_pred["output_slots_list"][0]["answer"]
        
        # Get raw scores
        score_true = 0
        score_false = 0
        for output_choice in json_pred['explicit_outputs']:
            if output_choice['output_text'] == "True":
                score_true = output_choice['output_prob']
            elif output_choice['output_text'] == "False":
                score_false = output_choice['output_prob']
                
        if  et_triplet_2_probTF[et_triplet_str]["answer"] not in ("True", "False") and score_true > 0 and score_false > 0:
            #print(et_triplet_str, et_triplet_2_probTF[et_triplet_str]["answer"], score_true,score_false)
            et_triplet_2_probTF[et_triplet_str]["answer"] = str(score_true > score_false)
            #print(et_triplet_2_probTF[et_triplet_str]["answer"])
                
        assert  et_triplet_2_probTF[et_triplet_str]["answer"] == "True" or  et_triplet_2_probTF[et_triplet_str]["answer"] == "False"
        
        # Scale to 100
        if score_true + score_false != 0.0:
            et_triplet_2_probTF[et_triplet_str]["prob_True"] = score_true/(score_false + score_true)
            et_triplet_2_probTF[et_triplet_str]["prob_False"] = 1 - et_triplet_2_probTF[et_triplet_str]["prob_True"]
        else:
            # if true and false not in the top options, label_True_False_probs stays as default
            print(statement, "Alert: true and false not in the options.")

# %%
print(model_name)
true_cnt = 0
for triplet_ans in et_triplet_2_probTF:
    for t in triplet_ans[1]:
        if t != t.strip():
            print(triplet_ans)
    if et_triplet_2_probTF[triplet_ans]['answer'] == 'True':
        true_cnt += 1
print("% True tuples: {}/{} ({})".format(true_cnt, len(et_triplet_2_probTF), round((true_cnt/len(et_triplet_2_probTF)) * 100, 2)))
# Out:
# Macaw-11B
# % True tuples: 62692/108528 (57.77)

# %%
def query_macaw_statements_batch_mode(device, perm):
    '''
    Input: everyday thing, list of tuples for permutation of list of parts
    Output: triplet_ans_conf_lst - contains [triplet,  ans, p_statement]
            neg_ans_conf_lst - list of p_neg_statement
    '''

    triplet_ans_conf_lst = [] # list of list
    neg_ans_conf_lst = [] # list
    for entry in perm:
        for rln in all_relations_lst:
            
            triplet = (entry[0], rln, entry[1])
            et_triplet_str = str((device, triplet))
            
            if et_triplet_str not in et_triplet_2_probTF:
                print("Need to query macaw online for", et_triplet_str)
                statement = triplet2statement(triplet)
                ans, p_statement, p_neg_statement = get_p_statement_and_p_neg_statement(device, statement)
            else:
                stored_data = et_triplet_2_probTF[et_triplet_str]
                ans = stored_data["answer"]
                p_statement = stored_data["prob_True"]
                p_neg_statement = stored_data["prob_False"]
            
            
            triplet_ans_conf_lst.append([triplet,  ans, p_statement])
            neg_ans_conf_lst.append(p_neg_statement)
            
    return triplet_ans_conf_lst, neg_ans_conf_lst

# query macaw on "everyday thing"
def run_query_macaw_everyday_thing_batch_mode(device, parts):
    # get parts
    perm = get_parts_perm(device, parts)
    # get macaw judgment
    triplet_ans_conf_lst, neg_ans_conf_lst = query_macaw_statements_batch_mode(device, perm)
    triplet_ans_conf_lst_true = get_statements_that_macaw_believesT(triplet_ans_conf_lst)
    return triplet_ans_conf_lst, triplet_ans_conf_lst_true, neg_ans_conf_lst

# %% [markdown]
# The next 2 cells are just for doing a sanity check with a small example:

# %%
triplet_ans_conf_lst, triplet_ans_conf_lst_true, neg_ans_conf_lst =\
    run_query_macaw_everyday_thing_batch_mode("egg", ['yolk', 'egg white', 'shell membrane', 'shell', 'air cell'])

# %%
triplet_ans_conf_lst, triplet_ans_conf_lst_true, neg_ans_conf_lst
# Out:
# ([[('yolk', 'part of', 'egg white'), 'False', 0.004708560493744304],
#   [('yolk', 'has part', 'egg white'), 'False', 0.34120868304130925],
#   [('yolk', 'inside', 'egg white'), 'True', 0.9118826352336734],
#   [('yolk', 'contains', 'egg white'), 'False', 0.12130310330302765],
#   [('yolk', 'in front of', 'egg white'), 'False', 0.38251589606806186],
#   [('yolk', 'behind', 'egg white'), 'False', 0.3635262971899514],
#   [('yolk', 'above', 'egg white'), 'True', 0.7750988644836971],
#   [('yolk', 'below', 'egg white'), 'True', 0.7171058899153786],
#   [('yolk', 'surrounds', 'egg white'), 'True', 0.943189790718785],
#   [('yolk', 'surrounded by', 'egg white'), 'True', 0.9868005561647796],
#   [('yolk', 'requires', 'egg white'), 'False', 0.15301443122687497],
#   [('yolk', 'required by', 'egg white'), 'False', 0.161191613819064],
#   [('yolk', 'connects', 'egg white'), 'True', 0.5136137525947052],
#   [('yolk', 'next to', 'egg white'), 'True', 0.7384337240733773],
#   [('yolk', 'part of', 'shell membrane'), 'False', 0.012524721500717756],
#   [('yolk', 'has part', 'shell membrane'), 'False', 0.2902262703482015],
#   [('yolk', 'inside', 'shell membrane'), 'True', 0.8782246477457287],
#   [('yolk', 'contains', 'shell membrane'), 'False', 0.062433979051538226],
#   [('yolk', 'in front of', 'shell membrane'), 'True', 0.6323842412636518],
#   [('yolk', 'behind', 'shell membrane'), 'True', 0.7995481455273544],
#   [('yolk', 'above', 'shell membrane'), 'True', 0.8830779662066143],
#   [('yolk', 'below', 'shell membrane'), 'True', 0.8248722864599557],
#   [('yolk', 'surrounds', 'shell membrane'), 'True', 0.8445605215220771],
#   [('yolk', 'surrounded by', 'shell membrane'), 'True', 0.9403201595948084],
#   [('yolk', 'requires', 'shell membrane'), 'False', 0.2717846011913502],
#   [('yolk', 'required by', 'shell membrane'), 'False', 0.04024621949904],
#   [('yolk', 'connects', 'shell membrane'), 'False', 0.0664436008459069],
#   [('yolk', 'next to', 'shell membrane'), 'False', 0.30929349517659127],
#   [('yolk', 'part of', 'shell'), 'False', 0.002470780585645453],
#   [('yolk', 'has part', 'shell'), 'False', 0.2533526258956345],
#   [('yolk', 'inside', 'shell'), 'True', 0.7953085459599795],
#   [('yolk', 'contains', 'shell'), 'False', 0.0408415891764575],
#   [('yolk', 'in front of', 'shell'), 'False', 0.33856341992025385],
#   [('yolk', 'behind', 'shell'), 'True', 0.6061641808853359],
#   [('yolk', 'above', 'shell'), 'True', 0.6531848301444806],
#   [('yolk', 'below', 'shell'), 'True', 0.6972838014178526],
#   [('yolk', 'surrounds', 'shell'), 'True', 0.7859707498062776],
#   [('yolk', 'surrounded by', 'shell'), 'True', 0.9114012529886415],
#   [('yolk', 'requires', 'shell'), 'False', 0.1193958045788677],
#   [('yolk', 'required by', 'shell'), 'False', 0.012426953913090448],
#   [('yolk', 'connects', 'shell'), 'False', 0.06801084458100849],
#   [('yolk', 'next to', 'shell'), 'False', 0.1669665473530076],
#   [('yolk', 'part of', 'air cell'), 'False', 0.005894625181694512],
#   [('yolk', 'has part', 'air cell'), 'False', 0.059699902954166856],
#   [('yolk', 'inside', 'air cell'), 'False', 0.13486798116126453],
#   [('yolk', 'contains', 'air cell'), 'False', 0.052905473902677934],
#   [('yolk', 'in front of', 'air cell'), 'False', 0.4087924241748082],
#   [('yolk', 'behind', 'air cell'), 'False', 0.3635985959780142],
#   [('yolk', 'above', 'air cell'), 'True', 0.7747198444516123],
#   [('yolk', 'below', 'air cell'), 'True', 0.6231135337864966],
#   [('yolk', 'surrounds', 'air cell'), 'False', 0.4464834281876997],
#   [('yolk', 'surrounded by', 'air cell'), 'False', 0.24311539563171042],
#   [('yolk', 'requires', 'air cell'), 'False', 0.10016532752678177],
#   [('yolk', 'required by', 'air cell'), 'False', 0.10133331867968563],
#   [('yolk', 'connects', 'air cell'), 'False', 0.006870376260595148],
#   [('yolk', 'next to', 'air cell'), 'False', 0.043160287935037324],
#   [('egg white', 'part of', 'yolk'), 'False', 0.03800571430438435],
#   [('egg white', 'has part', 'yolk'), 'False', 0.23666524407836978],
#   [('egg white', 'inside', 'yolk'), 'True', 0.6226559340374495],
#   [('egg white', 'contains', 'yolk'), 'False', 0.19777146379759752],
#   [('egg white', 'in front of', 'yolk'), 'False', 0.2808646952745984],
#   [('egg white', 'behind', 'yolk'), 'True', 0.5928708544058899],
#   [('egg white', 'above', 'yolk'), 'True', 0.8492023902983925],
#   [('egg white', 'below', 'yolk'), 'True', 0.6531597192113462],
#   [('egg white', 'surrounds', 'yolk'), 'True', 0.984170168552826],
#   [('egg white', 'surrounded by', 'yolk'), 'True', 0.9708645671907876],
#   [('egg white', 'requires', 'yolk'), 'False', 0.2324629943949919],
#   [('egg white', 'required by', 'yolk'), 'False', 0.079855439627694],
#   [('egg white', 'connects', 'yolk'), 'True', 0.6698137326820857],
#   [('egg white', 'next to', 'yolk'), 'True', 0.9118842213257321],
#   [('egg white', 'part of', 'shell membrane'), 'False', 0.01747019182942539],
#   [('egg white', 'has part', 'shell membrane'), 'False', 0.20041536262342036],
#   [('egg white', 'inside', 'shell membrane'), 'True', 0.8776897501424473],
#   [('egg white', 'contains', 'shell membrane'), 'False', 0.19125972748571993],
#   [('egg white', 'in front of', 'shell membrane'), 'True', 0.7260138432503686],
#   [('egg white', 'behind', 'shell membrane'), 'True', 0.7554239695371138],
#   [('egg white', 'above', 'shell membrane'), 'True', 0.9272547662089816],
#   [('egg white', 'below', 'shell membrane'), 'True', 0.6163357168495787],
#   [('egg white', 'surrounds', 'shell membrane'), 'True', 0.9097430887396306],
#   [('egg white', 'surrounded by', 'shell membrane'),
#    'True',
#    0.9428771271567628],
#   [('egg white', 'requires', 'shell membrane'), 'False', 0.16321908873208543],
#   [('egg white', 'required by', 'shell membrane'),
#    'False',
#    0.15841567429379216],
#   [('egg white', 'connects', 'shell membrane'), 'False', 0.08985666445539643],
#   [('egg white', 'next to', 'shell membrane'), 'True', 0.5288895265507139],
#   [('egg white', 'part of', 'shell'), 'False', 0.0045730198396666715],
#   [('egg white', 'has part', 'shell'), 'False', 0.3142752137783035],
#   [('egg white', 'inside', 'shell'), 'True', 0.891628527806803],
#   [('egg white', 'contains', 'shell'), 'False', 0.1721751401192926],
#   [('egg white', 'in front of', 'shell'), 'True', 0.6086708326990495],
#   [('egg white', 'behind', 'shell'), 'True', 0.7669210915712716],
#   [('egg white', 'above', 'shell'), 'True', 0.8844732300629847],
#   [('egg white', 'below', 'shell'), 'True', 0.6374165936021682],
#   [('egg white', 'surrounds', 'shell'), 'True', 0.9381890543247529],
#   [('egg white', 'surrounded by', 'shell'), 'True', 0.9735072479341211],
#   [('egg white', 'requires', 'shell'), 'False', 0.07873253087204037],
#   [('egg white', 'required by', 'shell'), 'False', 0.14943322482596003],
#   [('egg white', 'connects', 'shell'), 'False', 0.17926107635067842],
#   [('egg white', 'next to', 'shell'), 'True', 0.6075982819304421],
#   [('egg white', 'part of', 'air cell'), 'False', 0.1491451613752639],
#   [('egg white', 'has part', 'air cell'), 'False', 0.24232614995952734],
#   [('egg white', 'inside', 'air cell'), 'False', 0.46698235742220895],
#   [('egg white', 'contains', 'air cell'), 'False', 0.22933509834876528],
#   [('egg white', 'in front of', 'air cell'), 'True', 0.5000343633734643],
#   [('egg white', 'behind', 'air cell'), 'True', 0.5026543605135801],
#   [('egg white', 'above', 'air cell'), 'True', 0.8006535297743421],
#   [('egg white', 'below', 'air cell'), 'True', 0.5416626060245099],
#   [('egg white', 'surrounds', 'air cell'), 'True', 0.8724790899695237],
#   [('egg white', 'surrounded by', 'air cell'), 'True', 0.6645958680506239],
#   [('egg white', 'requires', 'air cell'), 'False', 0.2937856487539562],
#   [('egg white', 'required by', 'air cell'), 'False', 0.2781974674406785],
#   [('egg white', 'connects', 'air cell'), 'False', 0.10082973359155464],
#   [('egg white', 'next to', 'air cell'), 'False', 0.2550148110083825],
#   [('shell membrane', 'part of', 'yolk'), 'False', 0.2420941897275642],
#   [('shell membrane', 'has part', 'yolk'), 'False', 0.30493467949613784],
#   [('shell membrane', 'inside', 'yolk'), 'False', 0.4054467045005237],
#   [('shell membrane', 'contains', 'yolk'), 'True', 0.5567319748140624],
#   [('shell membrane', 'in front of', 'yolk'), 'True', 0.7629566644057173],
#   [('shell membrane', 'behind', 'yolk'), 'True', 0.8187448777029279],
#   [('shell membrane', 'above', 'yolk'), 'True', 0.9519888549262926],
#   [('shell membrane', 'below', 'yolk'), 'True', 0.8236332037679588],
#   [('shell membrane', 'surrounds', 'yolk'), 'True', 0.9789669618012683],
#   [('shell membrane', 'surrounded by', 'yolk'), 'True', 0.8487329723192177],
#   [('shell membrane', 'requires', 'yolk'), 'False', 0.3125813956605279],
#   [('shell membrane', 'required by', 'yolk'), 'False', 0.29092592552159585],
#   [('shell membrane', 'connects', 'yolk'), 'False', 0.3144657091529875],
#   [('shell membrane', 'next to', 'yolk'), 'True', 0.8039096268576187],
#   [('shell membrane', 'part of', 'egg white'), 'False', 0.29669313607693093],
#   [('shell membrane', 'has part', 'egg white'), 'True', 0.6132850237580613],
#   [('shell membrane', 'inside', 'egg white'), 'True', 0.7395005922349351],
#   [('shell membrane', 'contains', 'egg white'), 'True', 0.5658403399082792],
#   [('shell membrane', 'in front of', 'egg white'), 'True', 0.6889210243247221],
#   [('shell membrane', 'behind', 'egg white'), 'True', 0.9216339283718694],
#   [('shell membrane', 'above', 'egg white'), 'True', 0.9732002483848093],
#   [('shell membrane', 'below', 'egg white'), 'True', 0.9326328025970287],
#   [('shell membrane', 'surrounds', 'egg white'), 'True', 0.9808094282292371],
#   [('shell membrane', 'surrounded by', 'egg white'),
#    'True',
#    0.9338151623407789],
#   [('shell membrane', 'requires', 'egg white'), 'True', 0.6077542864797951],
#   [('shell membrane', 'required by', 'egg white'),
#    'False',
#    0.2723430449541302],
#   [('shell membrane', 'connects', 'egg white'), 'False', 0.4512699851778538],
#   [('shell membrane', 'next to', 'egg white'), 'True', 0.8185797238737897],
#   [('shell membrane', 'part of', 'shell'), 'True', 0.9844457159716091],
#   [('shell membrane', 'has part', 'shell'), 'True', 0.9428331070638922],
#   [('shell membrane', 'inside', 'shell'), 'True', 0.9550771833168749],
#   [('shell membrane', 'contains', 'shell'), 'True', 0.8971143211223032],
#   [('shell membrane', 'in front of', 'shell'), 'True', 0.7665478342196316],
#   [('shell membrane', 'behind', 'shell'), 'True', 0.9195302217423381],
#   [('shell membrane', 'above', 'shell'), 'True', 0.9072897834520343],
#   [('shell membrane', 'below', 'shell'), 'True', 0.8576217125414634],
#   [('shell membrane', 'surrounds', 'shell'), 'True', 0.9796009500307278],
#   [('shell membrane', 'surrounded by', 'shell'), 'True', 0.9817938964952794],
#   [('shell membrane', 'requires', 'shell'), 'True', 0.8590622861700147],
#   [('shell membrane', 'required by', 'shell'), 'True', 0.9276275429366305],
#   [('shell membrane', 'connects', 'shell'), 'True', 0.9414305522581098],
#   [('shell membrane', 'next to', 'shell'), 'True', 0.9590743270035195],
#   [('shell membrane', 'part of', 'air cell'), 'False', 0.13578081824024302],
#   [('shell membrane', 'has part', 'air cell'), 'False', 0.3700585712980866],
#   [('shell membrane', 'inside', 'air cell'), 'False', 0.46048393293254647],
#   [('shell membrane', 'contains', 'air cell'), 'False', 0.3289481211854899],
#   [('shell membrane', 'in front of', 'air cell'), 'True', 0.6887030540309834],
#   [('shell membrane', 'behind', 'air cell'), 'True', 0.8123076545030982],
#   [('shell membrane', 'above', 'air cell'), 'True', 0.953399604443662],
#   [('shell membrane', 'below', 'air cell'), 'True', 0.7994761560895625],
#   [('shell membrane', 'surrounds', 'air cell'), 'True', 0.835345597809967],
#   [('shell membrane', 'surrounded by', 'air cell'),
#    'True',
#    0.5180937469279485],
#   [('shell membrane', 'requires', 'air cell'), 'False', 0.4420191762607295],
#   [('shell membrane', 'required by', 'air cell'), 'True', 0.5021221435419422],
#   [('shell membrane', 'connects', 'air cell'), 'False', 0.20939681194080098],
#   [('shell membrane', 'next to', 'air cell'), 'True', 0.5008845939072584],
#   [('shell', 'part of', 'yolk'), 'False', 0.019993065092193344],
#   [('shell', 'has part', 'yolk'), 'False', 0.17984247506858908],
#   [('shell', 'inside', 'yolk'), 'False', 0.4012828585594808],
#   [('shell', 'contains', 'yolk'), 'False', 0.138657070743844],
#   [('shell', 'in front of', 'yolk'), 'True', 0.5981203245143186],
#   [('shell', 'behind', 'yolk'), 'True', 0.8311686638767405],
#   [('shell', 'above', 'yolk'), 'True', 0.9669962331376586],
#   [('shell', 'below', 'yolk'), 'True', 0.8839796691656224],
#   [('shell', 'surrounds', 'yolk'), 'True', 0.9916849428794151],
#   [('shell', 'surrounded by', 'yolk'), 'True', 0.8504312855511221],
#   [('shell', 'requires', 'yolk'), 'False', 0.14452524467122113],
#   [('shell', 'required by', 'yolk'), 'False', 0.13733085561960326],
#   [('shell', 'connects', 'yolk'), 'False', 0.18132093693855628],
#   [('shell', 'next to', 'yolk'), 'True', 0.8722615997440951],
#   [('shell', 'part of', 'egg white'), 'False', 0.042312826442877705],
#   [('shell', 'has part', 'egg white'), 'False', 0.3131017352508193],
#   [('shell', 'inside', 'egg white'), 'True', 0.8321429406928473],
#   [('shell', 'contains', 'egg white'), 'False', 0.18946987055060144],
#   [('shell', 'in front of', 'egg white'), 'True', 0.5866634062499599],
#   [('shell', 'behind', 'egg white'), 'True', 0.9277391818546681],
#   [('shell', 'above', 'egg white'), 'True', 0.9826063812231794],
#   [('shell', 'below', 'egg white'), 'True', 0.9593108824804811],
#   [('shell', 'surrounds', 'egg white'), 'True', 0.9945247264924165],
#   [('shell', 'surrounded by', 'egg white'), 'True', 0.9427473617035023],
#   [('shell', 'requires', 'egg white'), 'True', 0.5071528562513704],
#   [('shell', 'required by', 'egg white'), 'False', 0.234617859542909],
#   [('shell', 'connects', 'egg white'), 'False', 0.49223780383175686],
#   [('shell', 'next to', 'egg white'), 'True', 0.9223167438388633],
#   [('shell', 'part of', 'shell membrane'), 'True', 0.9527384497345982],
#   [('shell', 'has part', 'shell membrane'), 'True', 0.9431597861040751],
#   [('shell', 'inside', 'shell membrane'), 'True', 0.9358059021296445],
#   [('shell', 'contains', 'shell membrane'), 'True', 0.8254259249427158],
#   [('shell', 'in front of', 'shell membrane'), 'True', 0.7731952940356738],
#   [('shell', 'behind', 'shell membrane'), 'True', 0.9506554915105896],
#   [('shell', 'above', 'shell membrane'), 'True', 0.9586442672936701],
#   [('shell', 'below', 'shell membrane'), 'True', 0.7850492942225381],
#   [('shell', 'surrounds', 'shell membrane'), 'True', 0.9794996340144152],
#   [('shell', 'surrounded by', 'shell membrane'), 'True', 0.982114214943153],
#   [('shell', 'requires', 'shell membrane'), 'True', 0.8616428610668407],
#   [('shell', 'required by', 'shell membrane'), 'True', 0.8222054775346846],
#   [('shell', 'connects', 'shell membrane'), 'True', 0.9182136005806788],
#   [('shell', 'next to', 'shell membrane'), 'True', 0.9213734552677766],
#   [('shell', 'part of', 'air cell'), 'False', 0.12342177801247746],
#   [('shell', 'has part', 'air cell'), 'False', 0.3624165781707495],
#   [('shell', 'inside', 'air cell'), 'True', 0.5330852083106821],
#   [('shell', 'contains', 'air cell'), 'False', 0.30098164712932907],
#   [('shell', 'in front of', 'air cell'), 'True', 0.6508468786754609],
#   [('shell', 'behind', 'air cell'), 'True', 0.79916664778061],
#   [('shell', 'above', 'air cell'), 'True', 0.9372927961798013],
#   [('shell', 'below', 'air cell'), 'True', 0.8508321645741697],
#   [('shell', 'surrounds', 'air cell'), 'True', 0.9280236789859672],
#   [('shell', 'surrounded by', 'air cell'), 'True', 0.5846934852827645],
#   [('shell', 'requires', 'air cell'), 'False', 0.34521167054649254],
#   [('shell', 'required by', 'air cell'), 'False', 0.34186809768554155],
#   [('shell', 'connects', 'air cell'), 'False', 0.14086060955225393],
#   [('shell', 'next to', 'air cell'), 'False', 0.4507808774119457],
#   [('air cell', 'part of', 'yolk'), 'False', 0.03159424561925639],
#   [('air cell', 'has part', 'yolk'), 'False', 0.03842431559961203],
#   [('air cell', 'inside', 'yolk'), 'False', 0.1828612738989194],
#   [('air cell', 'contains', 'yolk'), 'False', 0.0372688262797226],
#   [('air cell', 'in front of', 'yolk'), 'False', 0.17778793166286105],
#   [('air cell', 'behind', 'yolk'), 'False', 0.24397348174401973],
#   [('air cell', 'above', 'yolk'), 'True', 0.5441417739806393],
#   [('air cell', 'below', 'yolk'), 'False', 0.18193078417713465],
#   [('air cell', 'surrounds', 'yolk'), 'False', 0.3826125917820267],
#   [('air cell', 'surrounded by', 'yolk'), 'False', 0.39396775399134804],
#   [('air cell', 'requires', 'yolk'), 'False', 0.1601885028029839],
#   [('air cell', 'required by', 'yolk'), 'False', 0.15061888942907808],
#   [('air cell', 'connects', 'yolk'), 'False', 0.01422379217711947],
#   [('air cell', 'next to', 'yolk'), 'False', 0.14764503608278065],
#   [('air cell', 'part of', 'egg white'), 'False', 0.4300238657558397],
#   [('air cell', 'has part', 'egg white'), 'False', 0.4527047336623989],
#   [('air cell', 'inside', 'egg white'), 'True', 0.7192746137487082],
#   [('air cell', 'contains', 'egg white'), 'False', 0.21771606124655407],
#   [('air cell', 'in front of', 'egg white'), 'False', 0.25124964989029297],
#   [('air cell', 'behind', 'egg white'), 'False', 0.4722409781892217],
#   [('air cell', 'above', 'egg white'), 'True', 0.6365519696371665],
#   [('air cell', 'below', 'egg white'), 'False', 0.37770736557163387],
#   [('air cell', 'surrounds', 'egg white'), 'True', 0.6142499807104164],
#   [('air cell', 'surrounded by', 'egg white'), 'True', 0.9163986391697334],
#   [('air cell', 'requires', 'egg white'), 'False', 0.4427557568431935],
#   [('air cell', 'required by', 'egg white'), 'False', 0.4827019721460584],
#   [('air cell', 'connects', 'egg white'), 'False', 0.16637676017588207],
#   [('air cell', 'next to', 'egg white'), 'False', 0.4165149449135853],
#   [('air cell', 'part of', 'shell membrane'), 'False', 0.46038163084336775],
#   [('air cell', 'has part', 'shell membrane'), 'False', 0.21281413526248233],
#   [('air cell', 'inside', 'shell membrane'), 'True', 0.6875079652105271],
#   [('air cell', 'contains', 'shell membrane'), 'False', 0.30313350538503675],
#   [('air cell', 'in front of', 'shell membrane'), 'False', 0.4085181049132838],
#   [('air cell', 'behind', 'shell membrane'), 'True', 0.6419232542432121],
#   [('air cell', 'above', 'shell membrane'), 'True', 0.7818977356133999],
#   [('air cell', 'below', 'shell membrane'), 'False', 0.44704777703065396],
#   [('air cell', 'surrounds', 'shell membrane'), 'True', 0.6994685048158544],
#   [('air cell', 'surrounded by', 'shell membrane'),
#    'True',
#    0.8206700440979482],
#   [('air cell', 'requires', 'shell membrane'), 'False', 0.4099323106016775],
#   [('air cell', 'required by', 'shell membrane'), 'False', 0.3091773113612048],
#   [('air cell', 'connects', 'shell membrane'), 'False', 0.16829047442465436],
#   [('air cell', 'next to', 'shell membrane'), 'False', 0.3958799514019143],
#   [('air cell', 'part of', 'shell'), 'True', 0.5123758077913665],
#   [('air cell', 'has part', 'shell'), 'False', 0.3198390206140888],
#   [('air cell', 'inside', 'shell'), 'True', 0.8375866172683358],
#   [('air cell', 'contains', 'shell'), 'False', 0.23805260300212316],
#   [('air cell', 'in front of', 'shell'), 'True', 0.5217601350236117],
#   [('air cell', 'behind', 'shell'), 'True', 0.7040809178386522],
#   [('air cell', 'above', 'shell'), 'True', 0.7633883671406587],
#   [('air cell', 'below', 'shell'), 'True', 0.5609678905177403],
#   [('air cell', 'surrounds', 'shell'), 'True', 0.7943850114596945],
#   [('air cell', 'surrounded by', 'shell'), 'True', 0.8844328345432161],
#   [('air cell', 'requires', 'shell'), 'True', 0.533058828149134],
#   [('air cell', 'required by', 'shell'), 'False', 0.42257830517700895],
#   [('air cell', 'connects', 'shell'), 'False', 0.1877004103929768],
#   [('air cell', 'next to', 'shell'), 'True', 0.5088480758871213]],
#  [[('yolk', 'inside', 'egg white'), 'True', 0.9118826352336734],
#   [('yolk', 'above', 'egg white'), 'True', 0.7750988644836971],
#   [('yolk', 'below', 'egg white'), 'True', 0.7171058899153786],
#   [('yolk', 'surrounds', 'egg white'), 'True', 0.943189790718785],
#   [('yolk', 'surrounded by', 'egg white'), 'True', 0.9868005561647796],
#   [('yolk', 'connects', 'egg white'), 'True', 0.5136137525947052],
#   [('yolk', 'next to', 'egg white'), 'True', 0.7384337240733773],
#   [('yolk', 'inside', 'shell membrane'), 'True', 0.8782246477457287],
#   [('yolk', 'in front of', 'shell membrane'), 'True', 0.6323842412636518],
#   [('yolk', 'behind', 'shell membrane'), 'True', 0.7995481455273544],
#   [('yolk', 'above', 'shell membrane'), 'True', 0.8830779662066143],
#   [('yolk', 'below', 'shell membrane'), 'True', 0.8248722864599557],
#   [('yolk', 'surrounds', 'shell membrane'), 'True', 0.8445605215220771],
#   [('yolk', 'surrounded by', 'shell membrane'), 'True', 0.9403201595948084],
#   [('yolk', 'inside', 'shell'), 'True', 0.7953085459599795],
#   [('yolk', 'behind', 'shell'), 'True', 0.6061641808853359],
#   [('yolk', 'above', 'shell'), 'True', 0.6531848301444806],
#   [('yolk', 'below', 'shell'), 'True', 0.6972838014178526],
#   [('yolk', 'surrounds', 'shell'), 'True', 0.7859707498062776],
#   [('yolk', 'surrounded by', 'shell'), 'True', 0.9114012529886415],
#   [('yolk', 'above', 'air cell'), 'True', 0.7747198444516123],
#   [('yolk', 'below', 'air cell'), 'True', 0.6231135337864966],
#   [('egg white', 'inside', 'yolk'), 'True', 0.6226559340374495],
#   [('egg white', 'behind', 'yolk'), 'True', 0.5928708544058899],
#   [('egg white', 'above', 'yolk'), 'True', 0.8492023902983925],
#   [('egg white', 'below', 'yolk'), 'True', 0.6531597192113462],
#   [('egg white', 'surrounds', 'yolk'), 'True', 0.984170168552826],
#   [('egg white', 'surrounded by', 'yolk'), 'True', 0.9708645671907876],
#   [('egg white', 'connects', 'yolk'), 'True', 0.6698137326820857],
#   [('egg white', 'next to', 'yolk'), 'True', 0.9118842213257321],
#   [('egg white', 'inside', 'shell membrane'), 'True', 0.8776897501424473],
#   [('egg white', 'in front of', 'shell membrane'), 'True', 0.7260138432503686],
#   [('egg white', 'behind', 'shell membrane'), 'True', 0.7554239695371138],
#   [('egg white', 'above', 'shell membrane'), 'True', 0.9272547662089816],
#   [('egg white', 'below', 'shell membrane'), 'True', 0.6163357168495787],
#   [('egg white', 'surrounds', 'shell membrane'), 'True', 0.9097430887396306],
#   [('egg white', 'surrounded by', 'shell membrane'),
#    'True',
#    0.9428771271567628],
#   [('egg white', 'next to', 'shell membrane'), 'True', 0.5288895265507139],
#   [('egg white', 'inside', 'shell'), 'True', 0.891628527806803],
#   [('egg white', 'in front of', 'shell'), 'True', 0.6086708326990495],
#   [('egg white', 'behind', 'shell'), 'True', 0.7669210915712716],
#   [('egg white', 'above', 'shell'), 'True', 0.8844732300629847],
#   [('egg white', 'below', 'shell'), 'True', 0.6374165936021682],
#   [('egg white', 'surrounds', 'shell'), 'True', 0.9381890543247529],
#   [('egg white', 'surrounded by', 'shell'), 'True', 0.9735072479341211],
#   [('egg white', 'next to', 'shell'), 'True', 0.6075982819304421],
#   [('egg white', 'in front of', 'air cell'), 'True', 0.5000343633734643],
#   [('egg white', 'behind', 'air cell'), 'True', 0.5026543605135801],
#   [('egg white', 'above', 'air cell'), 'True', 0.8006535297743421],
#   [('egg white', 'below', 'air cell'), 'True', 0.5416626060245099],
#   [('egg white', 'surrounds', 'air cell'), 'True', 0.8724790899695237],
#   [('egg white', 'surrounded by', 'air cell'), 'True', 0.6645958680506239],
#   [('shell membrane', 'contains', 'yolk'), 'True', 0.5567319748140624],
#   [('shell membrane', 'in front of', 'yolk'), 'True', 0.7629566644057173],
#   [('shell membrane', 'behind', 'yolk'), 'True', 0.8187448777029279],
#   [('shell membrane', 'above', 'yolk'), 'True', 0.9519888549262926],
#   [('shell membrane', 'below', 'yolk'), 'True', 0.8236332037679588],
#   [('shell membrane', 'surrounds', 'yolk'), 'True', 0.9789669618012683],
#   [('shell membrane', 'surrounded by', 'yolk'), 'True', 0.8487329723192177],
#   [('shell membrane', 'next to', 'yolk'), 'True', 0.8039096268576187],
#   [('shell membrane', 'has part', 'egg white'), 'True', 0.6132850237580613],
#   [('shell membrane', 'inside', 'egg white'), 'True', 0.7395005922349351],
#   [('shell membrane', 'contains', 'egg white'), 'True', 0.5658403399082792],
#   [('shell membrane', 'in front of', 'egg white'), 'True', 0.6889210243247221],
#   [('shell membrane', 'behind', 'egg white'), 'True', 0.9216339283718694],
#   [('shell membrane', 'above', 'egg white'), 'True', 0.9732002483848093],
#   [('shell membrane', 'below', 'egg white'), 'True', 0.9326328025970287],
#   [('shell membrane', 'surrounds', 'egg white'), 'True', 0.9808094282292371],
#   [('shell membrane', 'surrounded by', 'egg white'),
#    'True',
#    0.9338151623407789],
#   [('shell membrane', 'requires', 'egg white'), 'True', 0.6077542864797951],
#   [('shell membrane', 'next to', 'egg white'), 'True', 0.8185797238737897],
#   [('shell membrane', 'part of', 'shell'), 'True', 0.9844457159716091],
#   [('shell membrane', 'has part', 'shell'), 'True', 0.9428331070638922],
#   [('shell membrane', 'inside', 'shell'), 'True', 0.9550771833168749],
#   [('shell membrane', 'contains', 'shell'), 'True', 0.8971143211223032],
#   [('shell membrane', 'in front of', 'shell'), 'True', 0.7665478342196316],
#   [('shell membrane', 'behind', 'shell'), 'True', 0.9195302217423381],
#   [('shell membrane', 'above', 'shell'), 'True', 0.9072897834520343],
#   [('shell membrane', 'below', 'shell'), 'True', 0.8576217125414634],
#   [('shell membrane', 'surrounds', 'shell'), 'True', 0.9796009500307278],
#   [('shell membrane', 'surrounded by', 'shell'), 'True', 0.9817938964952794],
#   [('shell membrane', 'requires', 'shell'), 'True', 0.8590622861700147],
#   [('shell membrane', 'required by', 'shell'), 'True', 0.9276275429366305],
#   [('shell membrane', 'connects', 'shell'), 'True', 0.9414305522581098],
#   [('shell membrane', 'next to', 'shell'), 'True', 0.9590743270035195],
#   [('shell membrane', 'in front of', 'air cell'), 'True', 0.6887030540309834],
#   [('shell membrane', 'behind', 'air cell'), 'True', 0.8123076545030982],
#   [('shell membrane', 'above', 'air cell'), 'True', 0.953399604443662],
#   [('shell membrane', 'below', 'air cell'), 'True', 0.7994761560895625],
#   [('shell membrane', 'surrounds', 'air cell'), 'True', 0.835345597809967],
#   [('shell membrane', 'surrounded by', 'air cell'),
#    'True',
#    0.5180937469279485],
#   [('shell membrane', 'required by', 'air cell'), 'True', 0.5021221435419422],
#   [('shell membrane', 'next to', 'air cell'), 'True', 0.5008845939072584],
#   [('shell', 'in front of', 'yolk'), 'True', 0.5981203245143186],
#   [('shell', 'behind', 'yolk'), 'True', 0.8311686638767405],
#   [('shell', 'above', 'yolk'), 'True', 0.9669962331376586],
#   [('shell', 'below', 'yolk'), 'True', 0.8839796691656224],
#   [('shell', 'surrounds', 'yolk'), 'True', 0.9916849428794151],
#   [('shell', 'surrounded by', 'yolk'), 'True', 0.8504312855511221],
#   [('shell', 'next to', 'yolk'), 'True', 0.8722615997440951],
#   [('shell', 'inside', 'egg white'), 'True', 0.8321429406928473],
#   [('shell', 'in front of', 'egg white'), 'True', 0.5866634062499599],
#   [('shell', 'behind', 'egg white'), 'True', 0.9277391818546681],
#   [('shell', 'above', 'egg white'), 'True', 0.9826063812231794],
#   [('shell', 'below', 'egg white'), 'True', 0.9593108824804811],
#   [('shell', 'surrounds', 'egg white'), 'True', 0.9945247264924165],
#   [('shell', 'surrounded by', 'egg white'), 'True', 0.9427473617035023],
#   [('shell', 'requires', 'egg white'), 'True', 0.5071528562513704],
#   [('shell', 'next to', 'egg white'), 'True', 0.9223167438388633],
#   [('shell', 'part of', 'shell membrane'), 'True', 0.9527384497345982],
#   [('shell', 'has part', 'shell membrane'), 'True', 0.9431597861040751],
#   [('shell', 'inside', 'shell membrane'), 'True', 0.9358059021296445],
#   [('shell', 'contains', 'shell membrane'), 'True', 0.8254259249427158],
#   [('shell', 'in front of', 'shell membrane'), 'True', 0.7731952940356738],
#   [('shell', 'behind', 'shell membrane'), 'True', 0.9506554915105896],
#   [('shell', 'above', 'shell membrane'), 'True', 0.9586442672936701],
#   [('shell', 'below', 'shell membrane'), 'True', 0.7850492942225381],
#   [('shell', 'surrounds', 'shell membrane'), 'True', 0.9794996340144152],
#   [('shell', 'surrounded by', 'shell membrane'), 'True', 0.982114214943153],
#   [('shell', 'requires', 'shell membrane'), 'True', 0.8616428610668407],
#   [('shell', 'required by', 'shell membrane'), 'True', 0.8222054775346846],
#   [('shell', 'connects', 'shell membrane'), 'True', 0.9182136005806788],
#   [('shell', 'next to', 'shell membrane'), 'True', 0.9213734552677766],
#   [('shell', 'inside', 'air cell'), 'True', 0.5330852083106821],
#   [('shell', 'in front of', 'air cell'), 'True', 0.6508468786754609],
#   [('shell', 'behind', 'air cell'), 'True', 0.79916664778061],
#   [('shell', 'above', 'air cell'), 'True', 0.9372927961798013],
#   [('shell', 'below', 'air cell'), 'True', 0.8508321645741697],
#   [('shell', 'surrounds', 'air cell'), 'True', 0.9280236789859672],
#   [('shell', 'surrounded by', 'air cell'), 'True', 0.5846934852827645],
#   [('air cell', 'above', 'yolk'), 'True', 0.5441417739806393],
#   [('air cell', 'inside', 'egg white'), 'True', 0.7192746137487082],
#   [('air cell', 'above', 'egg white'), 'True', 0.6365519696371665],
#   [('air cell', 'surrounds', 'egg white'), 'True', 0.6142499807104164],
#   [('air cell', 'surrounded by', 'egg white'), 'True', 0.9163986391697334],
#   [('air cell', 'inside', 'shell membrane'), 'True', 0.6875079652105271],
#   [('air cell', 'behind', 'shell membrane'), 'True', 0.6419232542432121],
#   [('air cell', 'above', 'shell membrane'), 'True', 0.7818977356133999],
#   [('air cell', 'surrounds', 'shell membrane'), 'True', 0.6994685048158544],
#   [('air cell', 'surrounded by', 'shell membrane'),
#    'True',
#    0.8206700440979482],
#   [('air cell', 'part of', 'shell'), 'True', 0.5123758077913665],
#   [('air cell', 'inside', 'shell'), 'True', 0.8375866172683358],
#   [('air cell', 'in front of', 'shell'), 'True', 0.5217601350236117],
#   [('air cell', 'behind', 'shell'), 'True', 0.7040809178386522],
#   [('air cell', 'above', 'shell'), 'True', 0.7633883671406587],
#   [('air cell', 'below', 'shell'), 'True', 0.5609678905177403],
#   [('air cell', 'surrounds', 'shell'), 'True', 0.7943850114596945],
#   [('air cell', 'surrounded by', 'shell'), 'True', 0.8844328345432161],
#   [('air cell', 'requires', 'shell'), 'True', 0.533058828149134],
#   [('air cell', 'next to', 'shell'), 'True', 0.5088480758871213]],
#  [0.9952914395062556,
#   0.6587913169586908,
#   0.08811736476632659,
#   0.8786968966969724,
#   0.6174841039319381,
#   0.6364737028100487,
#   0.22490113551630286,
#   0.2828941100846214,
#   0.05681020928121505,
#   0.013199443835220426,
#   0.846985568773125,
#   0.838808386180936,
#   0.4863862474052948,
#   0.26156627592662274,
#   0.9874752784992823,
#   0.7097737296517985,
#   0.12177535225427127,
#   0.9375660209484618,
#   0.3676157587363482,
#   0.20045185447264557,
#   0.11692203379338573,
#   0.1751277135400443,
#   0.15543947847792294,
#   0.059679840405191587,
#   0.7282153988086498,
#   0.95975378050096,
#   0.933556399154093,
#   0.6907065048234087,
#   0.9975292194143546,
#   0.7466473741043655,
#   0.20469145404002054,
#   0.9591584108235425,
#   0.6614365800797462,
#   0.39383581911466414,
#   0.3468151698555194,
#   0.3027161985821474,
#   0.21402925019372243,
#   0.0885987470113585,
#   0.8806041954211323,
#   0.9875730460869095,
#   0.9319891554189915,
#   0.8330334526469925,
#   0.9941053748183055,
#   0.9403000970458332,
#   0.8651320188387355,
#   0.947094526097322,
#   0.5912075758251918,
#   0.6364014040219859,
#   0.22528015554838765,
#   0.3768864662135034,
#   0.5535165718123003,
#   0.7568846043682895,
#   0.8998346724732182,
#   0.8986666813203144,
#   0.9931296237394048,
#   0.9568397120649627,
#   0.9619942856956156,
#   0.7633347559216302,
#   0.37734406596255055,
#   0.8022285362024024,
#   0.7191353047254017,
#   0.40712914559411006,
#   0.1507976097016075,
#   0.3468402807886538,
#   0.01582983144717398,
#   0.02913543280921238,
#   0.7675370056050081,
#   0.920144560372306,
#   0.33018626731791434,
#   0.0881157786742679,
#   0.9825298081705746,
#   0.7995846373765796,
#   0.12231024985755268,
#   0.80874027251428,
#   0.27398615674963145,
#   0.24457603046288623,
#   0.07274523379101838,
#   0.38366428315042134,
#   0.09025691126036939,
#   0.05712287284323725,
#   0.8367809112679145,
#   0.8415843257062079,
#   0.9101433355446036,
#   0.47111047344928614,
#   0.9954269801603334,
#   0.6857247862216965,
#   0.10837147219319698,
#   0.8278248598807074,
#   0.39132916730095046,
#   0.23307890842872836,
#   0.11552676993701527,
#   0.3625834063978318,
#   0.06181094567524714,
#   0.026492752065878866,
#   0.9212674691279596,
#   0.85056677517404,
#   0.8207389236493216,
#   0.3924017180695579,
#   0.8508548386247361,
#   0.7576738500404727,
#   0.533017642577791,
#   0.7706649016512347,
#   0.4999656366265357,
#   0.49734563948641985,
#   0.19934647022565788,
#   0.4583373939754901,
#   0.12752091003047628,
#   0.3354041319493761,
#   0.7062143512460438,
#   0.7218025325593215,
#   0.8991702664084453,
#   0.7449851889916175,
#   0.7579058102724359,
#   0.6950653205038622,
#   0.5945532954994763,
#   0.44326802518593755,
#   0.2370433355942827,
#   0.18125512229707208,
#   0.048011145073707406,
#   0.1763667962320412,
#   0.0210330381987317,
#   0.15126702768078226,
#   0.6874186043394721,
#   0.7090740744784041,
#   0.6855342908470126,
#   0.1960903731423813,
#   0.7033068639230691,
#   0.38671497624193873,
#   0.26049940776506486,
#   0.4341596600917208,
#   0.31107897567527787,
#   0.07836607162813058,
#   0.02679975161519066,
#   0.06736719740297126,
#   0.019190571770762888,
#   0.06618483765922112,
#   0.3922457135202049,
#   0.7276569550458698,
#   0.5487300148221461,
#   0.18142027612621026,
#   0.015554284028390875,
#   0.05716689293610777,
#   0.044922816683125144,
#   0.10288567887769684,
#   0.23345216578036843,
#   0.08046977825766188,
#   0.09271021654796574,
#   0.14237828745853665,
#   0.02039904996927222,
#   0.018206103504720628,
#   0.14093771382998532,
#   0.07237245706336948,
#   0.05856944774189021,
#   0.04092567299648053,
#   0.864219181759757,
#   0.6299414287019134,
#   0.5395160670674535,
#   0.6710518788145101,
#   0.3112969459690166,
#   0.18769234549690184,
#   0.04660039555633799,
#   0.20052384391043754,
#   0.16465440219003302,
#   0.4819062530720515,
#   0.5579808237392705,
#   0.4978778564580578,
#   0.790603188059199,
#   0.49911540609274163,
#   0.9800069349078067,
#   0.8201575249314109,
#   0.5987171414405192,
#   0.861342929256156,
#   0.4018796754856814,
#   0.1688313361232595,
#   0.03300376686234141,
#   0.11602033083437757,
#   0.00831505712058489,
#   0.14956871444887787,
#   0.8554747553287789,
#   0.8626691443803968,
#   0.8186790630614438,
#   0.12773840025590488,
#   0.9576871735571223,
#   0.6868982647491807,
#   0.16785705930715267,
#   0.8105301294493985,
#   0.41333659375004006,
#   0.07226081814533192,
#   0.017393618776820552,
#   0.04068911751951887,
#   0.005475273507583478,
#   0.05725263829649774,
#   0.4928471437486296,
#   0.765382140457091,
#   0.5077621961682431,
#   0.0776832561611367,
#   0.0472615502654018,
#   0.05684021389592486,
#   0.06419409787035546,
#   0.17457407505728417,
#   0.22680470596432623,
#   0.04934450848941041,
#   0.04135573270632986,
#   0.2149507057774619,
#   0.0205003659855848,
#   0.017885785056847014,
#   0.13835713893315926,
#   0.17779452246531535,
#   0.0817863994193212,
#   0.07862654473222341,
#   0.8765782219875226,
#   0.6375834218292504,
#   0.46691479168931793,
#   0.6990183528706709,
#   0.34915312132453913,
#   0.20083335221939003,
#   0.06270720382019868,
#   0.14916783542583034,
#   0.07197632101403284,
#   0.41530651471723545,
#   0.6547883294535075,
#   0.6581319023144585,
#   0.859139390447746,
#   0.5492191225880543,
#   0.9684057543807436,
#   0.961575684400388,
#   0.8171387261010806,
#   0.9627311737202774,
#   0.822212068337139,
#   0.7560265182559802,
#   0.45585822601936066,
#   0.8180692158228653,
#   0.6173874082179733,
#   0.606032246008652,
#   0.8398114971970161,
#   0.8493811105709219,
#   0.9857762078228806,
#   0.8523549639172193,
#   0.5699761342441603,
#   0.5472952663376012,
#   0.28072538625129184,
#   0.7822839387534459,
#   0.748750350109707,
#   0.5277590218107783,
#   0.36344803036283346,
#   0.6222926344283661,
#   0.38575001928958363,
#   0.08360136083026659,
#   0.5572442431568065,
#   0.5172980278539416,
#   0.8336232398241179,
#   0.5834850550864147,
#   0.5396183691566323,
#   0.7871858647375176,
#   0.31249203478947285,
#   0.6968664946149632,
#   0.5914818950867162,
#   0.35807674575678794,
#   0.21810226438660008,
#   0.552952222969346,
#   0.30053149518414557,
#   0.1793299559020518,
#   0.5900676893983225,
#   0.6908226886387951,
#   0.8317095255753456,
#   0.6041200485980858,
#   0.4876241922086335,
#   0.6801609793859111,
#   0.16241338273166417,
#   0.7619473969978768,
#   0.47823986497638826,
#   0.29591908216134777,
#   0.23661163285934128,
#   0.4390321094822597,
#   0.20561498854030547,
#   0.11556716545678392,
#   0.46694117185086603,
#   0.5774216948229911,
#   0.8122995896070232,
#   0.49115192411287867])

# %% [markdown]
# # Part 2: Constraint satisfaction

# %%
def imagine_a_device_with_csp(device, turker, outputs_dir, filter_threshold, parts=[]):

    device = device.lower()
    tag = "threshold" + str(filter_threshold)
    
    lm_query_dir = outputs_dir + "LMResponses/" # dir where you want to save macaw output
    wcnf_dir = outputs_dir + "WCNF_format/" # dir where you want to save these wcnf for reference
    plots_dir = outputs_dir + "VizPlots/" # dir where you want to store output files
    statements_dir = outputs_dir + "Props/"# dir where you save data from this run
    all_results_filename = device.replace(" ", "-") + "_" + turker + "_" + tag
    for desired_dir in [outputs_dir, lm_query_dir, wcnf_dir, plots_dir, statements_dir]:
        make_sure_dir_exists(desired_dir)
    
    if all_results_filename + ".pkl" in os.listdir(statements_dir):
         # read
        with open(statements_dir + all_results_filename + ".pkl", 'rb') as f:
             all_result_dict = pickle.load(f)
        print("Read from file ...", len(all_result_dict["macaw_predictions"]), "triplets ...")
    else:
        # lm response - do not want to query LM again if the same device has been asked
        if device.replace(" ", "-") + "-" + turker + ".pkl" in os.listdir(lm_query_dir):
            # read
            with open(lm_query_dir + device.replace(" ", "-") + "-" + turker + ".pkl", 'rb') as f:
                 triplet_ans_conf_lst, triplet_ans_conf_lst_true, neg_ans_conf_lst = pickle.load(f) 
        else:
            # query macaw
            triplet_ans_conf_lst, triplet_ans_conf_lst_true, neg_ans_conf_lst = run_query_macaw_everyday_thing_batch_mode(device, parts)
            # save
            with open(lm_query_dir + device.replace(" ", "-") + "-" + turker + ".pkl", 'wb') as f:
                pickle.dump([triplet_ans_conf_lst, triplet_ans_conf_lst_true, neg_ans_conf_lst], f)

        # use maxsat
        print("Running maxsat ...", len(triplet_ans_conf_lst), "triplets...")
        model_believe_true_props, maxsat_selected_props = run_maxsat(device, turker, wcnf_dir, triplet_ans_conf_lst, neg_ans_conf_lst, triplet_ans_conf_lst_true, use_only_model_true_props = False)

        print("Filtering ...", len(model_believe_true_props), "triplets...", len(maxsat_selected_props), "triplets...")
        # filter based on confidence
        model_believe_true_props_filtered = filter_props(model_believe_true_props, filter_threshold)
        maxsat_selected_props_filtered = filter_props(maxsat_selected_props, filter_threshold)

        # plot
        print("Generating visualization ...", len(model_believe_true_props_filtered), "believed...", len(maxsat_selected_props_filtered), "selected")
        generate_graph_png(device, turker, model_believe_true_props_filtered, plots_dir, "model_believe_true_" + tag)
        generate_graph_png(device, turker, maxsat_selected_props_filtered, plots_dir, "maxsat_selected_" + tag)
        believed_selected= [k for k,v in model_believe_true_props_filtered.items() if k in maxsat_selected_props_filtered]
        generate_graph_png(device, turker, believed_selected, plots_dir, "believed_selected_" + tag)

        # save result
        all_result_dict = {"macaw_predictions": triplet_ans_conf_lst,\
                        "macaw_predictions_believe_true": triplet_ans_conf_lst_true,\
                        "model_believe_true_props": model_believe_true_props,\
                        "maxsat_selected_props": maxsat_selected_props,\
                        "filter_threshold": filter_threshold,\
                        "model_believe_true_props_filtered": model_believe_true_props_filtered,\
                        "maxsat_selected_props_filtered": maxsat_selected_props_filtered}

        with open(statements_dir + all_results_filename + ".pkl", 'wb') as f:
            pickle.dump(all_result_dict, f)
        print()
    return all_result_dict

# %%
outputs_dir = "0_" + model_name + "-ImagineADevice-CSP-Viz-full-ET-dataset/"
# # outputs_dir = "0_Macaw-3B-ImagineADevice-CSP-Viz-full-ET-dataset/"
# # outputs_dir = "0_Macaw-large-ImagineADevice-CSP-Viz-full-ET-dataset/"
# # outputs_dir = "0_UnifiedQA-ImagineADevice-CSP-Viz-full-ET-dataset/"
filter_threshold = 50

# %%
sorted_et2triplets_ann = sorted(et2triplets_ann, key=lambda et_turker: len(et2triplets_ann[et_turker]['parts-list']))

# %% [markdown]
# Be patient, we may encounter some formulae that will take longer to solve (like a few minutes)!

# %%
for mm_idx, et_turker in enumerate(sorted_et2triplets_ann) :
    print(et_turker, "MM #", mm_idx + 1)
        
    et, turker = et_turker
    parts_list = et2triplets_ann[et_turker]['parts-list']
    print(len(parts_list))
    all_result_dict = imagine_a_device_with_csp(et, turker, outputs_dir, filter_threshold, parts_list)

# %%
macaw_getMM_logfile.close()
impose_contraints_logfile.close()
