# %% [markdown]
# This notebook illustrates how we get:
# 1. Counts of how many relations per MM
# 2. Enrich relations via constraints
# 3. Counts of how many relations per MM after enriching (full-ET-dataset)

# %%
import csv
from utils import *

# %%
make_sure_dir_exists("enriched_mms")

# %%
from check_constraints import * 
from enrich_via_constraints import *
from relations import *

# %%
total_parts = []
min_parts_len = 10000
max_parts_len = 0
with open("../annotation-files/100everydaythings-Selected100_2022Oct31.tsv", "r") as tab1_info:
    tab1_data = csv.reader(tab1_info, delimiter="\t")
    for et_idx, line in enumerate(tab1_data):
        if et_idx < 1:
            continue
        parts = [p.strip() for p in line[1].split(",")]
        #print(et_idx, line)
        #print(parts)
        for part in parts:
            total_parts.append(part)
        len_parts = len(parts)
        if len_parts > max_parts_len:
            max_parts_len = len_parts
        if len_parts < min_parts_len:
            min_parts_len = len_parts

        

print("# parts given as seed (100 everyday things):", len(total_parts))
print("Min. # parts given as seed (100 everyday things):", min_parts_len)
print("Max. # parts given as seed (100 everyday things):", max_parts_len)
# Out:
# # parts given as seed (100 everyday things): 716
# Min. # parts given as seed (100 everyday things): 3
# Max. # parts given as seed (100 everyday things): 14

# %% [markdown]
# ## 1. Get transcribed MMs

# %%
et2triplets_ann = {}
ann_cnt = 0
for transcriber_idx in range(5):
    with open("../annotation-files/transcribed-turk-ann/Diagram-transcription - id" + str(transcriber_idx) + "_tab2.tsv") as infile:
        in_file_data = csv.reader(infile, delimiter = "\t")
        for line_idx, line in enumerate(in_file_data):

            # new set 
            if line[0] != "":
                et = line[1].lower()
                turker = line[0]
                et2triplets_ann[(et, turker)] = []

            
            new_relation_triplet = [entry.lower().strip() for entry in line[3:6]]
            assert new_relation_triplet[1]  in all_relations_lst
            if not(new_relation_triplet[0] and new_relation_triplet[1] and new_relation_triplet[2]):
                print(line_idx, line[3:6])
            if new_relation_triplet in et2triplets_ann[(et, turker)]:
                print(new_relation_triplet, "exists for", (et, turker), "[repeated entry]")
                continue
            et2triplets_ann[(et, turker)].append(new_relation_triplet)
            ann_cnt += 1
            
print(ann_cnt, "annotated relations")
# Out:
# ['foot rests', 'inside', 'deck'] exists for ('kayak', 'worker_100') [repeated entry]
# ['glass shell', 'above', 'metal base'] exists for ('lightbulb', 'worker_107') [repeated entry]
# ['top', 'above', 'carry handles'] exists for ('bird cage', 'worker_107') [repeated entry]
# ['top', 'above', 'rods'] exists for ('bird cage', 'worker_107') [repeated entry]
# ['control knob', 'part of', 'control panel'] exists for ('electric stove', 'worker_112') [repeated entry]
# ['leaves', 'part of', 'crown'] exists for ('tree', 'worker_107') [repeated entry]
# 2752 annotated relations

# %%
print("*" * 10, "Annotated MMs", "*" * 10)
parts = 0
total_relations = 0
relation_type_cnt = {"spatial": 0, "conectivity": 0, "functional": 0}
for et, turker in et2triplets_ann:
    relations = et2triplets_ann[(et, turker)]
    parts_local = []
    for p1, rln, p2 in relations:

        for p in (p1, p2):
            if p not in parts_local:
                parts_local.append(p)
        
        if rln == "connects":
            relation_type_cnt["conectivity"] += 1
        elif rln == "requires":
            relation_type_cnt["functional"] += 1
        else:
            relation_type_cnt["spatial"] += 1
        
    assert len(relations) > 1
    parts += len(parts_local)
    total_relations += len(relations)
    #print(et, turker, len(relations))
print("Total number of MMs annotated:", len(et2triplets_ann))
print("Total # parts annotated:", parts)
print("Total number of relations annotated:", total_relations)
for rt in relation_type_cnt:
    print(rt, "annotated: ", relation_type_cnt[rt])

print("Avg # parts annotated per MM:", round(parts/len(et2triplets_ann), 2) )
print("Avg. number of relations per MM:", round(total_relations/len(et2triplets_ann),2))
for rt in relation_type_cnt:
    print(rt, "annotated (avg): ", round(relation_type_cnt[rt]/len(et2triplets_ann),2))
# Out:
# ********** Annotated MMs **********
# Total number of MMs annotated: 300
# Total # parts annotated: 2191
# Total number of relations annotated: 2752
# spatial annotated:  1858
# conectivity annotated:  818
# functional annotated:  76
# Avg # parts annotated per MM: 7.3
# Avg. number of relations per MM: 9.17
# spatial annotated (avg):  6.19
# conectivity annotated (avg):  2.73
# functional annotated (avg):  0.25

# %%
v = 0
t = 0
for et, turker in et2triplets_ann:
    relations = et2triplets_ann[(et, turker)]
    relations_tuples = [tuple(triplet) for triplet in relations]
    print(et, turker, len(relations))
    violations, total = get_asymmetric_constraint_violations(relations_tuples, verbose=False)
    v += violations
    t += total
print("Overall consistency violation: {numerator}/{denominator} ({percentage})".format(numerator=v,\
    denominator=t, percentage=round(v/t,2)))
# Out:
# air conditioner worker_100 4
# [CONSTRAINT TYPE2]
# Consistency violation: 0/0
# Not applicable for given mental model!
# air conditioner worker_101 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# air conditioner worker_102 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# bicycle worker_101 17
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# bicycle worker_102 11
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# bicycle worker_103 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# binoculars worker_101 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/0
# Not applicable for given mental model!
# binoculars worker_102 7
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# binoculars worker_100 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/1 (0.0))
# blender worker_101 11
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# blender worker_100 7
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# blender worker_104 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# boat worker_100 10
# [CONSTRAINT TYPE2]
# Consistency violation: 0/9 (0.0))
# boat worker_102 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# boat worker_103 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/1 (0.0))
# digital camera worker_101 11
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# digital camera worker_100 7
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# digital camera worker_105 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# elevator worker_101 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# elevator worker_106 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# elevator worker_102 7
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# flashlight worker_101 13
# [CONSTRAINT TYPE2]
# Consistency violation: 0/10 (0.0))
# flashlight worker_102 7
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# flashlight worker_107 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# glider worker_101 12
# [CONSTRAINT TYPE2]
# Consistency violation: 0/9 (0.0))
# glider worker_100 12
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# glider worker_102 11
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# guitar worker_101 17
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# guitar worker_104 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# guitar worker_102 10
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# house worker_100 10
# [CONSTRAINT TYPE2]
# Consistency violation: 0/7 (0.0))
# house worker_101 19
# [CONSTRAINT TYPE2]
# Consistency violation: 0/7 (0.0))
# house worker_102 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# laptop worker_103 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# laptop worker_101 4
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# laptop worker_102 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# pencil sharpener worker_101 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# pencil sharpener worker_100 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# pencil sharpener worker_102 3
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# pillow worker_101 2
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# pillow worker_102 2
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# pillow worker_107 2
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# stroller worker_101 17
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# stroller worker_102 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# stroller worker_100 11
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# table fan worker_106 11
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# table fan worker_100 7
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# table fan worker_102 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# truck worker_101 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/7 (0.0))
# truck worker_100 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# truck worker_102 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# washing machine worker_101 14
# [CONSTRAINT TYPE2]
# Consistency violation: 0/7 (0.0))
# washing machine worker_102 12
# [CONSTRAINT TYPE2]
# Consistency violation: 0/9 (0.0))
# washing machine worker_103 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# wheelchair worker_101 20
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# wheelchair worker_102 12
# [CONSTRAINT TYPE2]
# Consistency violation: 0/7 (0.0))
# wheelchair worker_100 15
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# zipper worker_101 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# zipper worker_100 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# zipper worker_102 7
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# apple worker_101 7
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# apple worker_108 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# apple worker_100 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# barbeque grill worker_103 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# barbeque grill worker_102 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# barbeque grill worker_104 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# coffee maker worker_101 10
# [CONSTRAINT TYPE2]
# Consistency violation: 0/10 (0.0))
# coffee maker worker_103 12
# [CONSTRAINT TYPE2]
# Consistency violation: 0/12 (0.0))
# coffee maker worker_102 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# digital clinical thermometer worker_101 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/0
# Not applicable for given mental model!
# digital clinical thermometer worker_102 3
# [CONSTRAINT TYPE2]
# Consistency violation: 0/0
# Not applicable for given mental model!
# digital clinical thermometer worker_104 4
# [CONSTRAINT TYPE2]
# Consistency violation: 0/0
# Not applicable for given mental model!
# dishwasher worker_105 15
# [CONSTRAINT TYPE2]
# Consistency violation: 0/11 (0.0))
# dishwasher worker_100 16
# [CONSTRAINT TYPE2]
# Consistency violation: 0/11 (0.0))
# dishwasher worker_104 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# door worker_101 16
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# door worker_100 10
# [CONSTRAINT TYPE2]
# Consistency violation: 0/7 (0.0))
# door worker_104 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# dryer worker_101 12
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# dryer worker_106 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/7 (0.0))
# dryer worker_102 7
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# earphone worker_107 4
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# earphone worker_101 4
# [CONSTRAINT TYPE2]
# Consistency violation: 0/1 (0.0))
# earphone worker_102 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# fish worker_101 11
# [CONSTRAINT TYPE2]
# Consistency violation: 0/11 (0.0))
# fish worker_100 14
# [CONSTRAINT TYPE2]
# Consistency violation: 0/14 (0.0))
# fish worker_102 10
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# flower worker_107 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# flower worker_101 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# flower worker_102 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# kayak worker_100 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# kayak worker_101 13
# [CONSTRAINT TYPE2]
# Consistency violation: 0/9 (0.0))
# kayak worker_102 13
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# kite worker_101 12
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# kite worker_109 10
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# kite worker_100 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# microphone worker_101 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/1 (0.0))
# microphone worker_100 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/1 (0.0))
# microphone worker_107 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# pencil worker_107 4
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# pencil worker_101 4
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# pencil worker_102 4
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# ship worker_102 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/7 (0.0))
# ship worker_104 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# ship worker_103 11
# [CONSTRAINT TYPE2]
# Consistency violation: 0/9 (0.0))
# suitcase worker_101 14
# [CONSTRAINT TYPE2]
# Consistency violation: 0/7 (0.0))
# suitcase worker_100 13
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# suitcase worker_102 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# teapot worker_101 4
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# teapot worker_102 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# teapot worker_107 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# telephone worker_101 11
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# telephone worker_102 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/1 (0.0))
# telephone worker_107 14
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# telescope worker_102 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# telescope worker_100 11
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# telescope worker_106 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# windmill worker_107 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# windmill worker_101 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# windmill worker_102 4
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# backpack worker_103 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# backpack worker_102 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# backpack worker_100 7
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# deer worker_101 19
# [CONSTRAINT TYPE2]
# Consistency violation: 0/7 (0.0))
# deer worker_100 13
# [CONSTRAINT TYPE2]
# Consistency violation: 0/11 (0.0))
# deer worker_102 17
# [CONSTRAINT TYPE2]
# Consistency violation: 0/10 (0.0))
# dog worker_101 18
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# dog worker_102 11
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# dog worker_107 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# doorbell worker_101 4
# [CONSTRAINT TYPE2]
# Consistency violation: 0/0
# Not applicable for given mental model!
# doorbell worker_102 4
# [CONSTRAINT TYPE2]
# Consistency violation: 0/0
# Not applicable for given mental model!
# doorbell worker_107 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/0
# Not applicable for given mental model!
# fire extinguisher worker_101 14
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# fire extinguisher worker_102 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# fire extinguisher worker_100 13
# [CONSTRAINT TYPE2]
# Consistency violation: 0/10 (0.0))
# hair dryer worker_101 21
# [CONSTRAINT TYPE2]
# Consistency violation: 0/7 (0.0))
# hair dryer worker_100 13
# [CONSTRAINT TYPE2]
# Consistency violation: 0/9 (0.0))
# hair dryer worker_102 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# ink pen worker_101 11
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# ink pen worker_100 13
# [CONSTRAINT TYPE2]
# Consistency violation: 0/9 (0.0))
# ink pen worker_102 7
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# lightbulb worker_107 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# lightbulb worker_101 11
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# lightbulb worker_102 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/7 (0.0))
# microscope worker_101 18
# [CONSTRAINT TYPE2]
# Consistency violation: 0/7 (0.0))
# microscope worker_102 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# microscope worker_104 10
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# rabbit worker_103 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# rabbit worker_101 21
# [CONSTRAINT TYPE2]
# Consistency violation: 0/13 (0.0))
# rabbit worker_102 14
# [CONSTRAINT TYPE2]
# Consistency violation: 0/9 (0.0))
# refrigerator worker_102 7
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# refrigerator worker_100 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# refrigerator worker_104 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# rocket worker_100 15
# [CONSTRAINT TYPE2]
# Consistency violation: 0/15 (0.0))
# rocket worker_108 11
# [CONSTRAINT TYPE2]
# Consistency violation: 0/9 (0.0))
# rocket worker_102 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/9 (0.0))
# sandwich worker_101 2
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# sandwich worker_100 4
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# sandwich worker_102 2
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# screw worker_101 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# screw worker_102 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# screw worker_107 3
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# space heater worker_106 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# space heater worker_107 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# space heater worker_100 10
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# toaster worker_101 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# toaster worker_104 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# toaster worker_102 7
# [CONSTRAINT TYPE2]
# Consistency violation: 0/7 (0.0))
# typewriter worker_102 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# typewriter worker_103 13
# [CONSTRAINT TYPE2]
# Consistency violation: 0/11 (0.0))
# typewriter worker_100 7
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# violin worker_101 16
# [CONSTRAINT TYPE2]
# Consistency violation: 0/7 (0.0))
# violin worker_104 10
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# violin worker_102 12
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# wall clock worker_101 10
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# wall clock worker_102 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# wall clock worker_107 10
# [CONSTRAINT TYPE2]
# Consistency violation: 0/10 (0.0))
# window worker_101 3
# [CONSTRAINT TYPE2]
# Consistency violation: 0/1 (0.0))
# window worker_102 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# window worker_107 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# bat worker_103 14
# [CONSTRAINT TYPE2]
# Consistency violation: 0/9 (0.0))
# bat worker_102 10
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# bat worker_100 13
# [CONSTRAINT TYPE2]
# Consistency violation: 0/9 (0.0))
# bird worker_107 10
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# bird worker_101 15
# [CONSTRAINT TYPE2]
# Consistency violation: 0/9 (0.0))
# bird worker_102 14
# [CONSTRAINT TYPE2]
# Consistency violation: 0/10 (0.0))
# bookcase worker_107 20
# [CONSTRAINT TYPE2]
# Consistency violation: 0/12 (0.0))
# bookcase worker_101 12
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# bookcase worker_102 7
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# bus worker_101 15
# [CONSTRAINT TYPE2]
# Consistency violation: 0/10 (0.0))
# bus worker_104 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/7 (0.0))
# bus worker_102 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# butterfly worker_110 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# butterfly worker_101 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# butterfly worker_102 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# cable car worker_111 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# cable car worker_101 10
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# cable car worker_102 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# calculator worker_101 11
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# calculator worker_106 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# calculator worker_107 19
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# cat worker_107 17
# [CONSTRAINT TYPE2]
# Consistency violation: 0/9 (0.0))
# cat worker_100 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/7 (0.0))
# cat worker_101 22
# [CONSTRAINT TYPE2]
# Consistency violation: 0/14 (0.0))
# chair worker_103 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# chair worker_102 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# chair worker_100 10
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# computer worker_101 7
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# computer worker_102 7
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# computer worker_100 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# duck worker_101 17
# [CONSTRAINT TYPE2]
# Consistency violation: 0/7 (0.0))
# duck worker_100 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# duck worker_102 13
# [CONSTRAINT TYPE2]
# Consistency violation: 0/7 (0.0))
# egg worker_101 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# egg worker_103 3
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# egg worker_102 4
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# helicopter worker_101 13
# [CONSTRAINT TYPE2]
# Consistency violation: 0/9 (0.0))
# helicopter worker_102 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/7 (0.0))
# helicopter worker_106 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# knife worker_101 20
# [CONSTRAINT TYPE2]
# Consistency violation: 0/12 (0.0))
# knife worker_102 13
# [CONSTRAINT TYPE2]
# Consistency violation: 0/10 (0.0))
# knife worker_104 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# photo frame worker_106 3
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# photo frame worker_101 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# photo frame worker_107 3
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# rice cooker worker_100 12
# [CONSTRAINT TYPE2]
# Consistency violation: 0/9 (0.0))
# rice cooker worker_102 10
# [CONSTRAINT TYPE2]
# Consistency violation: 0/9 (0.0))
# rice cooker worker_103 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# saucepan worker_101 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# saucepan worker_100 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# saucepan worker_104 4
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# shoe worker_101 11
# [CONSTRAINT TYPE2]
# Consistency violation: 0/7 (0.0))
# shoe worker_102 13
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# shoe worker_104 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# train worker_106 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/1 (0.0))
# train worker_103 14
# [CONSTRAINT TYPE2]
# Consistency violation: 0/14 (0.0))
# train worker_102 13
# [CONSTRAINT TYPE2]
# Consistency violation: 0/10 (0.0))
# umbrella worker_100 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# umbrella worker_101 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# umbrella worker_104 4
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# airplane worker_101 15
# [CONSTRAINT TYPE2]
# Consistency violation: 0/12 (0.0))
# airplane worker_102 12
# [CONSTRAINT TYPE2]
# Consistency violation: 0/10 (0.0))
# airplane worker_104 7
# [CONSTRAINT TYPE2]
# Consistency violation: 0/7 (0.0))
# baby bottle worker_101 11
# [CONSTRAINT TYPE2]
# Consistency violation: 0/9 (0.0))
# baby bottle worker_102 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# baby bottle worker_107 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# bed worker_101 7
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# bed worker_102 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# bed worker_107 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/1 (0.0))
# bird cage worker_107 29
# [CONSTRAINT TYPE2]
# Consistency violation: 0/14 (0.0))
# bird cage worker_101 10
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# bird cage worker_104 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# car worker_101 16
# [CONSTRAINT TYPE2]
# Consistency violation: 0/14 (0.0))
# car worker_104 7
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# car worker_100 14
# [CONSTRAINT TYPE2]
# Consistency violation: 0/11 (0.0))
# chainsaw worker_101 10
# [CONSTRAINT TYPE2]
# Consistency violation: 0/9 (0.0))
# chainsaw worker_102 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# chainsaw worker_107 15
# [CONSTRAINT TYPE2]
# Consistency violation: 0/11 (0.0))
# corn worker_101 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# corn worker_100 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# corn worker_107 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# cow worker_102 16
# [CONSTRAINT TYPE2]
# Consistency violation: 0/11 (0.0))
# cow worker_100 13
# [CONSTRAINT TYPE2]
# Consistency violation: 0/10 (0.0))
# cow worker_104 7
# [CONSTRAINT TYPE2]
# Consistency violation: 0/7 (0.0))
# electric stove worker_102 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# electric stove worker_112 12
# [CONSTRAINT TYPE2]
# Consistency violation: 0/12 (0.0))
# electric stove worker_103 11
# [CONSTRAINT TYPE2]
# Consistency violation: 0/11 (0.0))
# electric tea kettle worker_102 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# electric tea kettle worker_104 7
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# electric tea kettle worker_107 13
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# hot air balloon worker_100 15
# [CONSTRAINT TYPE2]
# Consistency violation: 0/9 (0.0))
# hot air balloon worker_101 12
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# hot air balloon worker_102 15
# [CONSTRAINT TYPE2]
# Consistency violation: 0/11 (0.0))
# humidifier worker_100 13
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# humidifier worker_102 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# humidifier worker_104 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# microwave worker_101 11
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# microwave worker_107 10
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# microwave worker_103 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# piano worker_101 9
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# piano worker_106 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# piano worker_103 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# rat worker_101 21
# [CONSTRAINT TYPE2]
# Consistency violation: 0/13 (0.0))
# rat worker_102 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/5 (0.0))
# rat worker_103 7
# [CONSTRAINT TYPE2]
# Consistency violation: 0/7 (0.0))
# stethoscope worker_101 13
# [CONSTRAINT TYPE2]
# Consistency violation: 0/7 (0.0))
# stethoscope worker_102 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# stethoscope worker_104 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# table worker_101 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# table worker_102 6
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# table worker_104 4
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# table lamp worker_108 12
# [CONSTRAINT TYPE2]
# Consistency violation: 0/11 (0.0))
# table lamp worker_104 8
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# table lamp worker_100 13
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# tent worker_101 7
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# tent worker_102 7
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# tent worker_103 5
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# tree worker_101 12
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# tree worker_102 11
# [CONSTRAINT TYPE2]
# Consistency violation: 0/7 (0.0))
# tree worker_107 7
# [CONSTRAINT TYPE2]
# Consistency violation: 0/3 (0.0))
# Overall consistency violation: 0/1704 (0.0)

# %% [markdown]
# ## 2. Enrich via constraints

# %%
_= mini_ET_dataset.write("\t".join(["everyday-thing", "turker", "triplet", "label"]) + "\n")

# %%
v = 0
t = 0
print("Enriching with 4 types of constraints ...")
print("*" * 10, "Annotated + Enriched MMs", "*" * 10)
parts = []
total_in_data = 0
ans_true = 0
ans_false = 0
relation_type_cnt = {"spatial": 0, "conectivity": 0, "functional": 0}

for et, turker in et2triplets_ann:
    enrich_logfile.write(et + " " + turker + "\n")
    enrich_cnts_logfile.write(et + " " + turker + "\n")
    added_relations_logfile.write(et + " " + turker + "...")
    # enrich
    ann_relations = et2triplets_ann[(et, turker)]
    relations = [] # no duplicates
    for rln in ann_relations:
        if rln not in relations:
            relations.append(rln)
    all_relations = get_all_relations_with_labels(relations, verbose = False)
    print(et, turker, "Before:", len(relations), "After:",  len(all_relations))
    
    #relations_tuples_check = {triplet[0]: triplet[1] for triplet in all_relations}
    relations_tuples_check = [triplet[0] for triplet in all_relations if triplet[1]]
    violations, total = get_all_constraint_violations(relations_tuples_check, verbose=False, max_sat_applied=False)
    v += violations
    t += total

    parts_local = []
    # store relations
    for triplet, label in all_relations:
        mini_ET_dataset.write("\t".join([et, turker, str(triplet), str(label)]) + "\n")
        total_in_data += 1
        if label:
            ans_true += 1
        else:
            ans_false += 1
            
        # get some stats
        p1, rln, p2 = triplet
        for p in (p1, p2):
            if p not in parts_local:
                parts_local.append(p)
        
        if rln == "connects":
            relation_type_cnt["conectivity"] += 1
        elif rln == "requires":
            relation_type_cnt["functional"] += 1
        else:
            relation_type_cnt["spatial"] += 1
    parts += parts_local
        

enrich_logfile.close() 
enrich_cnts_logfile.close()
added_relations_logfile.close()
mini_ET_dataset.close()
# Out:
# Enriching with 4 types of constraints ...
# ********** Annotated + Enriched MMs **********
# air conditioner worker_100 Before: 4 After: 8
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE3]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/4 (0.0))
# air conditioner worker_101 Before: 6 After: 16
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/10 (0.0))
# air conditioner worker_102 Before: 8 After: 24
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/16 (0.0))
# bicycle worker_101 Before: 17 After: 44
# [CONSTRAINT TYPE1]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/10 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/27 (0.0))
# bicycle worker_102 Before: 11 After: 30
# [CONSTRAINT TYPE1]
# Consistency violation: 0/7 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/19 (0.0))
# bicycle worker_103 Before: 8 After: 30
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/23 (0.0))
# binoculars worker_101 Before: 8 After: 16
# [CONSTRAINT TYPE1]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE3]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/8 (0.0))
# binoculars worker_102 Before: 7 After: 42
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/18 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/9 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/14 (0.0))
# [===OVERALL==]
# Consistency violation: 0/44 (0.0))
# binoculars worker_100 Before: 6 After: 14
# [CONSTRAINT TYPE1]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/8 (0.0))
# blender worker_101 Before: 11 After: 44
# [CONSTRAINT TYPE1]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/16 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/8 (0.0))
# [===OVERALL==]
# Consistency violation: 0/38 (0.0))
# blender worker_100 Before: 7 After: 22
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/15 (0.0))
# blender worker_104 Before: 8 After: 56
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/26 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/13 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/22 (0.0))
# [===OVERALL==]
# Consistency violation: 0/63 (0.0))
# boat worker_100 Before: 10 After: 70
# [CONSTRAINT TYPE1]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/34 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/17 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/32 (0.0))
# [===OVERALL==]
# Consistency violation: 0/84 (0.0))
# boat worker_102 Before: 9 After: 28
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/10 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/19 (0.0))
# boat worker_103 Before: 6 After: 14
# [CONSTRAINT TYPE1]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/8 (0.0))
# digital camera worker_101 Before: 11 After: 28
# [CONSTRAINT TYPE1]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/17 (0.0))
# digital camera worker_100 Before: 7 After: 26
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/10 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/20 (0.0))
# digital camera worker_105 Before: 8 After: 32
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/4 (0.0))
# [===OVERALL==]
# Consistency violation: 0/26 (0.0))
# elevator worker_101 Before: 9 After: 58
# [CONSTRAINT TYPE1]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/28 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/14 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/18 (0.0))
# [===OVERALL==]
# Consistency violation: 0/61 (0.0))
# elevator worker_106 Before: 8 After: 76
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/38 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/19 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/42 (0.0))
# [===OVERALL==]
# Consistency violation: 0/99 (0.0))
# elevator worker_102 Before: 7 After: 18
# [CONSTRAINT TYPE1]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/11 (0.0))
# flashlight worker_101 Before: 13 After: 66
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/30 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/15 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/14 (0.0))
# [===OVERALL==]
# Consistency violation: 0/62 (0.0))
# flashlight worker_102 Before: 7 After: 30
# [CONSTRAINT TYPE1]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/14 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/7 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/24 (0.0))
# flashlight worker_107 Before: 8 After: 52
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/26 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/13 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/14 (0.0))
# [===OVERALL==]
# Consistency violation: 0/53 (0.0))
# glider worker_101 Before: 12 After: 42
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/18 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/9 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/30 (0.0))
# glider worker_100 Before: 12 After: 38
# [CONSTRAINT TYPE1]
# Consistency violation: 0/7 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/27 (0.0))
# glider worker_102 Before: 11 After: 36
# [CONSTRAINT TYPE1]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/26 (0.0))
# guitar worker_101 Before: 17 After: 46
# [CONSTRAINT TYPE1]
# Consistency violation: 0/11 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/29 (0.0))
# guitar worker_104 Before: 6 After: 26
# [CONSTRAINT TYPE1]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/21 (0.0))
# guitar worker_102 Before: 10 After: 36
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/16 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/26 (0.0))
# house worker_100 Before: 10 After: 34
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/14 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/7 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/24 (0.0))
# house worker_101 Before: 19 After: 56
# [CONSTRAINT TYPE1]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/16 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/38 (0.0))
# house worker_102 Before: 9 After: 24
# [CONSTRAINT TYPE1]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/15 (0.0))
# laptop worker_103 Before: 5 After: 28
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/8 (0.0))
# [===OVERALL==]
# Consistency violation: 0/28 (0.0))
# laptop worker_101 Before: 4 After: 18
# [CONSTRAINT TYPE1]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/15 (0.0))
# laptop worker_102 Before: 5 After: 18
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/14 (0.0))
# pencil sharpener worker_101 Before: 6 After: 20
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/14 (0.0))
# pencil sharpener worker_100 Before: 6 After: 18
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/12 (0.0))
# pencil sharpener worker_102 Before: 3 After: 12
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/9 (0.0))
# pillow worker_101 Before: 2 After: 12
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/11 (0.0))
# pillow worker_102 Before: 2 After: 12
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/11 (0.0))
# pillow worker_107 Before: 2 After: 8
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/6 (0.0))
# stroller worker_101 Before: 17 After: 56
# [CONSTRAINT TYPE1]
# Consistency violation: 0/10 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/18 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/9 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/8 (0.0))
# [===OVERALL==]
# Consistency violation: 0/45 (0.0))
# stroller worker_102 Before: 8 After: 44
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/20 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/10 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/10 (0.0))
# [===OVERALL==]
# Consistency violation: 0/42 (0.0))
# stroller worker_100 Before: 11 After: 78
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/36 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/18 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/34 (0.0))
# [===OVERALL==]
# Consistency violation: 0/91 (0.0))
# table fan worker_106 Before: 11 After: 38
# [CONSTRAINT TYPE1]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/14 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/7 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/28 (0.0))
# table fan worker_100 Before: 7 After: 20
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/13 (0.0))
# table fan worker_102 Before: 6 After: 36
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/18 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/9 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/8 (0.0))
# [===OVERALL==]
# Consistency violation: 0/35 (0.0))
# truck worker_101 Before: 9 After: 36
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/16 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/4 (0.0))
# [===OVERALL==]
# Consistency violation: 0/30 (0.0))
# truck worker_100 Before: 8 After: 24
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/16 (0.0))
# truck worker_102 Before: 6 After: 26
# [CONSTRAINT TYPE1]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/21 (0.0))
# washing machine worker_101 Before: 14 After: 42
# [CONSTRAINT TYPE1]
# Consistency violation: 0/7 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/14 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/7 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/28 (0.0))
# washing machine worker_102 Before: 12 After: 74
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/34 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/17 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/24 (0.0))
# [===OVERALL==]
# Consistency violation: 0/78 (0.0))
# washing machine worker_103 Before: 8 After: 52
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/26 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/13 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/12 (0.0))
# [===OVERALL==]
# Consistency violation: 0/51 (0.0))
# wheelchair worker_101 Before: 20 After: 56
# [CONSTRAINT TYPE1]
# Consistency violation: 0/14 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/14 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/7 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/37 (0.0))
# wheelchair worker_102 Before: 12 After: 50
# [CONSTRAINT TYPE1]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/20 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/10 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/6 (0.0))
# [===OVERALL==]
# Consistency violation: 0/41 (0.0))
# wheelchair worker_100 Before: 15 After: 48
# [CONSTRAINT TYPE1]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/8 (0.0))
# [===OVERALL==]
# Consistency violation: 0/38 (0.0))
# zipper worker_101 Before: 9 After: 24
# [CONSTRAINT TYPE1]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/15 (0.0))
# zipper worker_100 Before: 9 After: 28
# [CONSTRAINT TYPE1]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/20 (0.0))
# zipper worker_102 Before: 7 After: 20
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/13 (0.0))
# apple worker_101 Before: 7 After: 32
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/14 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/7 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/4 (0.0))
# [===OVERALL==]
# Consistency violation: 0/27 (0.0))
# apple worker_108 Before: 6 After: 20
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/14 (0.0))
# apple worker_100 Before: 5 After: 20
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/16 (0.0))
# barbeque grill worker_103 Before: 8 After: 30
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/23 (0.0))
# barbeque grill worker_102 Before: 8 After: 56
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/26 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/13 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/20 (0.0))
# [===OVERALL==]
# Consistency violation: 0/61 (0.0))
# barbeque grill worker_104 Before: 8 After: 28
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/10 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/21 (0.0))
# coffee maker worker_101 Before: 10 After: 56
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/28 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/14 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/10 (0.0))
# [===OVERALL==]
# Consistency violation: 0/52 (0.0))
# coffee maker worker_103 Before: 12 After: 84
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/42 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/21 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/28 (0.0))
# [===OVERALL==]
# Consistency violation: 0/91 (0.0))
# coffee maker worker_102 Before: 6 After: 48
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/24 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/16 (0.0))
# [===OVERALL==]
# Consistency violation: 0/52 (0.0))
# digital clinical thermometer worker_101 Before: 6 After: 12
# [CONSTRAINT TYPE1]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE3]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/6 (0.0))
# digital clinical thermometer worker_102 Before: 3 After: 6
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE3]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/3 (0.0))
# digital clinical thermometer worker_104 Before: 4 After: 8
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE3]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/4 (0.0))
# dishwasher worker_105 Before: 15 After: 92
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/42 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/21 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/28 (0.0))
# [===OVERALL==]
# Consistency violation: 0/95 (0.0))
# dishwasher worker_100 Before: 16 After: 90
# [CONSTRAINT TYPE1]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/40 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/20 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/26 (0.0))
# [===OVERALL==]
# Consistency violation: 0/91 (0.0))
# dishwasher worker_104 Before: 6 After: 30
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/8 (0.0))
# [===OVERALL==]
# Consistency violation: 0/29 (0.0))
# door worker_101 Before: 16 After: 38
# [CONSTRAINT TYPE1]
# Consistency violation: 0/13 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/22 (0.0))
# door worker_100 Before: 10 After: 34
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/14 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/7 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/24 (0.0))
# door worker_104 Before: 6 After: 34
# [CONSTRAINT TYPE1]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/16 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/8 (0.0))
# [===OVERALL==]
# Consistency violation: 0/33 (0.0))
# dryer worker_101 Before: 12 After: 32
# [CONSTRAINT TYPE1]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/20 (0.0))
# dryer worker_106 Before: 8 After: 70
# [CONSTRAINT TYPE1]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/34 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/17 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/40 (0.0))
# [===OVERALL==]
# Consistency violation: 0/92 (0.0))
# dryer worker_102 Before: 7 After: 30
# [CONSTRAINT TYPE1]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/14 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/7 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/24 (0.0))
# earphone worker_107 Before: 4 After: 16
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/13 (0.0))
# earphone worker_101 Before: 4 After: 10
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/6 (0.0))
# earphone worker_102 Before: 5 After: 16
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/11 (0.0))
# fish worker_101 Before: 11 After: 156
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/78 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/39 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/132 (0.0))
# [===OVERALL==]
# Consistency violation: 0/249 (0.0))
# fish worker_100 Before: 14 After: 180
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/90 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/45 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/192 (0.0))
# [===OVERALL==]
# Consistency violation: 0/327 (0.0))
# fish worker_102 Before: 10 After: 52
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/24 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/10 (0.0))
# [===OVERALL==]
# Consistency violation: 0/48 (0.0))
# flower worker_107 Before: 5 After: 16
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/11 (0.0))
# flower worker_101 Before: 9 After: 32
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/24 (0.0))
# flower worker_102 Before: 8 After: 30
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/23 (0.0))
# kayak worker_100 Before: 8 After: 36
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/18 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/9 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/29 (0.0))
# kayak worker_101 Before: 13 After: 104
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/48 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/24 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/70 (0.0))
# [===OVERALL==]
# Consistency violation: 0/146 (0.0))
# kayak worker_102 Before: 13 After: 66
# [CONSTRAINT TYPE1]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/28 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/14 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/20 (0.0))
# [===OVERALL==]
# Consistency violation: 0/67 (0.0))
# kite worker_101 Before: 12 After: 32
# [CONSTRAINT TYPE1]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/20 (0.0))
# kite worker_109 Before: 10 After: 44
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/18 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/9 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/8 (0.0))
# [===OVERALL==]
# Consistency violation: 0/39 (0.0))
# kite worker_100 Before: 8 After: 20
# [CONSTRAINT TYPE1]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/12 (0.0))
# microphone worker_101 Before: 5 After: 12
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/7 (0.0))
# microphone worker_100 Before: 5 After: 12
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/7 (0.0))
# microphone worker_107 Before: 9 After: 30
# [CONSTRAINT TYPE1]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/10 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/22 (0.0))
# pencil worker_107 Before: 4 After: 18
# [CONSTRAINT TYPE1]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/15 (0.0))
# pencil worker_101 Before: 4 After: 40
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/20 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/10 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/20 (0.0))
# [===OVERALL==]
# Consistency violation: 0/50 (0.0))
# pencil worker_102 Before: 4 After: 12
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/8 (0.0))
# ship worker_102 Before: 8 After: 38
# [CONSTRAINT TYPE1]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/18 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/9 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/4 (0.0))
# [===OVERALL==]
# Consistency violation: 0/32 (0.0))
# ship worker_104 Before: 5 After: 42
# [CONSTRAINT TYPE1]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/20 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/10 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/20 (0.0))
# [===OVERALL==]
# Consistency violation: 0/51 (0.0))
# ship worker_103 Before: 11 After: 48
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/22 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/11 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/4 (0.0))
# [===OVERALL==]
# Consistency violation: 0/39 (0.0))
# suitcase worker_101 Before: 14 After: 62
# [CONSTRAINT TYPE1]
# Consistency violation: 0/7 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/24 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/12 (0.0))
# [===OVERALL==]
# Consistency violation: 0/55 (0.0))
# suitcase worker_100 Before: 13 After: 36
# [CONSTRAINT TYPE1]
# Consistency violation: 0/10 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/24 (0.0))
# suitcase worker_102 Before: 9 After: 26
# [CONSTRAINT TYPE1]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/17 (0.0))
# teapot worker_101 Before: 4 After: 16
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/13 (0.0))
# teapot worker_102 Before: 6 After: 22
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/17 (0.0))
# teapot worker_107 Before: 5 After: 20
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/16 (0.0))
# telephone worker_101 Before: 11 After: 34
# [CONSTRAINT TYPE1]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/23 (0.0))
# telephone worker_102 Before: 6 After: 14
# [CONSTRAINT TYPE1]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/8 (0.0))
# telephone worker_107 Before: 14 After: 40
# [CONSTRAINT TYPE1]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/26 (0.0))
# telescope worker_102 Before: 8 After: 48
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/24 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/8 (0.0))
# [===OVERALL==]
# Consistency violation: 0/44 (0.0))
# telescope worker_100 Before: 11 After: 44
# [CONSTRAINT TYPE1]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/16 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/8 (0.0))
# [===OVERALL==]
# Consistency violation: 0/38 (0.0))
# telescope worker_106 Before: 6 After: 20
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/14 (0.0))
# windmill worker_107 Before: 5 After: 20
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/16 (0.0))
# windmill worker_101 Before: 5 After: 18
# [CONSTRAINT TYPE1]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/13 (0.0))
# windmill worker_102 Before: 4 After: 16
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/13 (0.0))
# backpack worker_103 Before: 6 After: 18
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/12 (0.0))
# backpack worker_102 Before: 9 After: 32
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/24 (0.0))
# backpack worker_100 Before: 7 After: 18
# [CONSTRAINT TYPE1]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/11 (0.0))
# deer worker_101 Before: 19 After: 70
# [CONSTRAINT TYPE1]
# Consistency violation: 0/11 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/24 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/12 (0.0))
# [===OVERALL==]
# Consistency violation: 0/59 (0.0))
# deer worker_100 Before: 13 After: 72
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/34 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/17 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/16 (0.0))
# [===OVERALL==]
# Consistency violation: 0/69 (0.0))
# deer worker_102 Before: 17 After: 64
# [CONSTRAINT TYPE1]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/26 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/13 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/6 (0.0))
# [===OVERALL==]
# Consistency violation: 0/51 (0.0))
# dog worker_101 Before: 18 After: 66
# [CONSTRAINT TYPE1]
# Consistency violation: 0/9 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/24 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/10 (0.0))
# [===OVERALL==]
# Consistency violation: 0/55 (0.0))
# dog worker_102 Before: 11 After: 34
# [CONSTRAINT TYPE1]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/23 (0.0))
# dog worker_107 Before: 9 After: 28
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/10 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/19 (0.0))
# doorbell worker_101 Before: 4 After: 8
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE3]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/4 (0.0))
# doorbell worker_102 Before: 4 After: 8
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE3]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/4 (0.0))
# doorbell worker_107 Before: 5 After: 10
# [CONSTRAINT TYPE1]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE3]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/5 (0.0))
# fire extinguisher worker_101 Before: 14 After: 38
# [CONSTRAINT TYPE1]
# Consistency violation: 0/9 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/10 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/24 (0.0))
# fire extinguisher worker_102 Before: 9 After: 26
# [CONSTRAINT TYPE1]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/17 (0.0))
# fire extinguisher worker_100 Before: 13 After: 50
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/22 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/11 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/38 (0.0))
# hair dryer worker_101 Before: 21 After: 84
# [CONSTRAINT TYPE1]
# Consistency violation: 0/14 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/28 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/14 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/16 (0.0))
# [===OVERALL==]
# Consistency violation: 0/72 (0.0))
# hair dryer worker_100 Before: 13 After: 48
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/20 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/10 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/36 (0.0))
# hair dryer worker_102 Before: 8 After: 26
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/10 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/18 (0.0))
# ink pen worker_101 Before: 11 After: 42
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/18 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/9 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/32 (0.0))
# ink pen worker_100 Before: 13 After: 56
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/24 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/8 (0.0))
# [===OVERALL==]
# Consistency violation: 0/48 (0.0))
# ink pen worker_102 Before: 7 After: 22
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/15 (0.0))
# lightbulb worker_107 Before: 5 After: 14
# [CONSTRAINT TYPE1]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/10 (0.0))
# lightbulb worker_101 Before: 11 After: 42
# [CONSTRAINT TYPE1]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/16 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/4 (0.0))
# [===OVERALL==]
# Consistency violation: 0/33 (0.0))
# lightbulb worker_102 Before: 9 After: 36
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/16 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/28 (0.0))
# microscope worker_101 Before: 18 After: 78
# [CONSTRAINT TYPE1]
# Consistency violation: 0/11 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/28 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/14 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/18 (0.0))
# [===OVERALL==]
# Consistency violation: 0/71 (0.0))
# microscope worker_102 Before: 9 After: 34
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/14 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/7 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/26 (0.0))
# microscope worker_104 Before: 10 After: 44
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/18 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/9 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/6 (0.0))
# [===OVERALL==]
# Consistency violation: 0/37 (0.0))
# rabbit worker_103 Before: 9 After: 62
# [CONSTRAINT TYPE1]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/30 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/15 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/22 (0.0))
# [===OVERALL==]
# Consistency violation: 0/68 (0.0))
# ...
# bird cage worker_101 Before: 10 After: 32
# [CONSTRAINT TYPE1]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/10 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/23 (0.0))
# bird cage worker_104 Before: 6 After: 40
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/20 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/10 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/14 (0.0))
# [===OVERALL==]
# Consistency violation: 0/44 (0.0))
# car worker_101 Before: 16 After: 116
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/56 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/28 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/50 (0.0))
# [===OVERALL==]
# Consistency violation: 0/136 (0.0))
# car worker_104 Before: 7 After: 32
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/14 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/7 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/4 (0.0))
# [===OVERALL==]
# Consistency violation: 0/27 (0.0))
# car worker_100 Before: 14 After: 58
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/26 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/13 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/6 (0.0))
# [===OVERALL==]
# Consistency violation: 0/48 (0.0))
# chainsaw worker_101 Before: 10 After: 54
# [CONSTRAINT TYPE1]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/26 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/13 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/10 (0.0))
# [===OVERALL==]
# Consistency violation: 0/50 (0.0))
# chainsaw worker_102 Before: 8 After: 28
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/20 (0.0))
# chainsaw worker_107 Before: 15 After: 52
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/22 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/11 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/37 (0.0))
# corn worker_101 Before: 5 After: 18
# [CONSTRAINT TYPE1]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/13 (0.0))
# corn worker_100 Before: 5 After: 18
# [CONSTRAINT TYPE1]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/13 (0.0))
# corn worker_107 Before: 5 After: 20
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/10 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/15 (0.0))
# cow worker_102 Before: 16 After: 54
# [CONSTRAINT TYPE1]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/22 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/11 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/38 (0.0))
# cow worker_100 Before: 13 After: 50
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/22 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/11 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/38 (0.0))
# cow worker_104 Before: 7 After: 88
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/44 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/22 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/70 (0.0))
# [===OVERALL==]
# Consistency violation: 0/136 (0.0))
# electric stove worker_102 Before: 8 After: 44
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/22 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/11 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/8 (0.0))
# [===OVERALL==]
# Consistency violation: 0/41 (0.0))
# electric stove worker_112 Before: 12 After: 60
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/30 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/15 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/8 (0.0))
# [===OVERALL==]
# Consistency violation: 0/53 (0.0))
# electric stove worker_103 Before: 11 After: 56
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/28 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/14 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/8 (0.0))
# [===OVERALL==]
# Consistency violation: 0/50 (0.0))
# electric tea kettle worker_102 Before: 9 After: 30
# [CONSTRAINT TYPE1]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/10 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/22 (0.0))
# electric tea kettle worker_104 Before: 7 After: 28
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/22 (0.0))
# electric tea kettle worker_107 Before: 13 After: 46
# [CONSTRAINT TYPE1]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/18 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/9 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/4 (0.0))
# [===OVERALL==]
# Consistency violation: 0/36 (0.0))
# hot air balloon worker_100 Before: 15 After: 52
# [CONSTRAINT TYPE1]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/20 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/10 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/38 (0.0))
# hot air balloon worker_101 Before: 12 After: 52
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/22 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/11 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/8 (0.0))
# [===OVERALL==]
# Consistency violation: 0/45 (0.0))
# hot air balloon worker_102 Before: 15 After: 60
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/26 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/13 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/4 (0.0))
# [===OVERALL==]
# Consistency violation: 0/47 (0.0))
# humidifier worker_100 Before: 13 After: 54
# [CONSTRAINT TYPE1]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/22 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/11 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/8 (0.0))
# [===OVERALL==]
# Consistency violation: 0/46 (0.0))
# humidifier worker_102 Before: 6 After: 36
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/18 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/9 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/8 (0.0))
# [===OVERALL==]
# Consistency violation: 0/35 (0.0))
# humidifier worker_104 Before: 6 After: 20
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/15 (0.0))
# microwave worker_101 Before: 11 After: 34
# [CONSTRAINT TYPE1]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/23 (0.0))
# microwave worker_107 Before: 10 After: 40
# [CONSTRAINT TYPE1]
# Consistency violation: 0/2 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/18 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/9 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/31 (0.0))
# microwave worker_103 Before: 8 After: 36
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/18 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/9 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/29 (0.0))
# piano worker_101 Before: 9 After: 66
# [CONSTRAINT TYPE1]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/32 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/16 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/22 (0.0))
# [===OVERALL==]
# Consistency violation: 0/71 (0.0))
# piano worker_106 Before: 5 After: 24
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/20 (0.0))
# piano worker_103 Before: 5 After: 30
# [CONSTRAINT TYPE1]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/14 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/7 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/8 (0.0))
# [===OVERALL==]
# Consistency violation: 0/30 (0.0))
# rat worker_101 Before: 21 After: 76
# [CONSTRAINT TYPE1]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/30 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/15 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/4 (0.0))
# [===OVERALL==]
# Consistency violation: 0/57 (0.0))
# rat worker_102 Before: 5 After: 24
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/12 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/20 (0.0))
# rat worker_103 Before: 7 After: 40
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/20 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/10 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/8 (0.0))
# [===OVERALL==]
# Consistency violation: 0/38 (0.0))
# stethoscope worker_101 Before: 13 After: 44
# [CONSTRAINT TYPE1]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/16 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/32 (0.0))
# stethoscope worker_102 Before: 6 After: 18
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/12 (0.0))
# stethoscope worker_104 Before: 5 After: 18
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/14 (0.0))
# table worker_101 Before: 6 After: 20
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/15 (0.0))
# table worker_102 Before: 6 After: 18
# [CONSTRAINT TYPE1]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/2 (0.0))
# [===OVERALL==]
# Consistency violation: 0/14 (0.0))
# table worker_104 Before: 4 After: 22
# [CONSTRAINT TYPE1]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/10 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/5 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/4 (0.0))
# [===OVERALL==]
# Consistency violation: 0/20 (0.0))
# table lamp worker_108 Before: 12 After: 54
# [CONSTRAINT TYPE1]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/26 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/13 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/4 (0.0))
# [===OVERALL==]
# Consistency violation: 0/44 (0.0))
# table lamp worker_104 Before: 8 After: 44
# [CONSTRAINT TYPE1]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [CONSTRAINT TYPE2]
# Consistency violation: 0/22 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/11 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/12 (0.0))
# [===OVERALL==]
# Consistency violation: 0/45 (0.0))
# table lamp worker_100 Before: 13 After: 32
# [CONSTRAINT TYPE1]
# Consistency violation: 0/10 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/19 (0.0))
# tent worker_101 Before: 7 After: 34
# [CONSTRAINT TYPE1]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/16 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/4 (0.0))
# [===OVERALL==]
# Consistency violation: 0/29 (0.0))
# tent worker_102 Before: 7 After: 20
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/13 (0.0))
# tent worker_103 Before: 5 After: 18
# [CONSTRAINT TYPE1]
# Consistency violation: 0/1 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/8 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/13 (0.0))
# tree worker_101 Before: 12 After: 30
# [CONSTRAINT TYPE1]
# Consistency violation: 0/9 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/18 (0.0))
# tree worker_102 Before: 11 After: 44
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/18 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/9 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/4 (0.0))
# [===OVERALL==]
# Consistency violation: 0/35 (0.0))
# tree worker_107 Before: 7 After: 20
# [CONSTRAINT TYPE1]
# Consistency violation: 0/4 (0.0))
# [CONSTRAINT TYPE2]
# Consistency violation: 0/6 (0.0))
# [CONSTRAINT TYPE3]
# Consistency violation: 0/3 (0.0))
# [CONSTRAINT TYPE4]
# Consistency violation: 0/0
# Not applicable for given mental model!
# [===OVERALL==]
# Consistency violation: 0/13 (0.0))

# %%
print("Total number of MMs annotated:", len(et2triplets_ann))
print("Total # parts annotated:", len(parts))
print("Total number of relations with TRUE label:", ans_true)
print("Total number of relations with FALSE label:", ans_false)
print("Total number of relations in our data:", total_in_data)
for rt in relation_type_cnt:
    print(rt, "annotated: ", relation_type_cnt[rt])
    
print("Avg # parts annotated per MM:", round(len(parts)/len(et2triplets_ann), 2) )
print("Avg. number of relations per MM:", round(total_in_data/len(et2triplets_ann),2))
for rt in relation_type_cnt:
    print(rt, "annotated (avg): ", round(relation_type_cnt[rt]/len(et2triplets_ann),2))
print("Overall consistency violation: {numerator}/{denominator} ({percentage})".format(numerator=v,\
    denominator=t, percentage=round(v/t,2)))
# Out:
# Total number of MMs annotated: 300
# Total # parts annotated: 2191
# Total number of relations with TRUE label: 6894
# Total number of relations with FALSE label: 4826
# Total number of relations in our data: 11720
# spatial annotated:  9956
# conectivity annotated:  1612
# functional annotated:  152
# Avg # parts annotated per MM: 7.3
# Avg. number of relations per MM: 39.07
# spatial annotated (avg):  33.19
# conectivity annotated (avg):  5.37
# functional annotated (avg):  0.51
# Overall consistency violation: 0/10615 (0.0)

# %% [markdown]
# After running this notebook, you should see an additional folder named "enriched_mms" which constains the logs for the enrichment done above, as well as full-ET-dataset.tsv which is our full dataset.
